# %% [markdown]
# # Multi-user IoU
#
# For the machine learning algorithm to work it is crucial to establish a satistfactory ground-truth. We probably don't have to deal with spammers in our dataset but still with persons who were interpreting our classes differently. So the question this notebook likes to answer is:
#
# **How to connect user scores with each other?**
#
# In order to establish these connections, one could set all bilateral user scores (e.g. IoU) into relationship. In the following, the IoUs are calculated on the full dataset for every combination of users that have classified a specific image with a specific class. The averaged user-user IoUs are shown in a matrix and are sorted by there standard deviation. A user with a low standard deviation, meaning that all his IoUs with other users are similar ( not necessarily high!). Based on such a matrix, one could try to find the centroid of these IoUs.
# For three users I would think this could work as follows: each user pair (permutations and identities ignored) gets one dimension.
# user1-user2: IoU as radius
# user1-user3: IoU as azimuth
# user2-user3: IoU as elevation
# From those three points in a sphere the centroid can be easily found. Defining a sphere around this centroid with radius r could be used as a threshold. Points within that sphere are regareded as 'good classifiers' and outside as 'bad classifiers'.
# With four users and more this gets much more complicated as the number of pairs is higher than the number of users, however this would be my current idea.

# %%
from pyclouds import iou
from pyclouds.imports import *
from tqdm import tqdm_notebook as tqdm
from itertools import product
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pyclouds.zooniverse import *
from pyclouds.helpers import *

# %%
clas_in = '../zooniverse_raw/sugar-flower-fish-or-gravel-classifications_18_12_16.csv'
subj_in = '../zooniverse_raw/sugar-flower-fish-or-gravel-subjects_18_11_05.csv'
img_size = (2100, 1400)

# %%
classes = ['Sugar', 'Flower', 'Fish', 'Gravel']

# %%
subj = load_classifications(subj_in)

# %%
subjects_name = {60811:'BCO_DJF_Aqua',60812:'BCO_DJF_Terra',60813: 'BCO_MAM_Aqua',\
                 60814: 'BCO_MAM_Terra',60815:'R2_DJF_Aqua',60816:'R2_DJF_Terra',\
                 60817:'R3_DJF_Aqua', 60818:'R3_DJF_Terra',60819:'R3_SON_Aqua',\
                 60835: 'R3_SON_Terra'}

# %%
subj2fn = {}
for i, r in subj.iterrows():
    if r['subject_set_id'] in list(subjects_name.keys()):
        subj2fn[r['subject_id']] =  r['metadata']['fn']

# %%
clas = parse_classifications(clas_in,json_columns=['metadata', 'annotations', 'subject_data'])

# %%
clas['datetime'] = pd.to_datetime(clas['created_at'])

# %%
clas_full = clas[(clas['workflow_name'] == 'Full dataset')]

# %%
clas_full.head()
# Out:
#     classification_id                           user_name    user_id  \
# 13          128932300                         raspstephan  1814911.0
# 23          129485502  not-logged-in-80bdc4acf6d39d1ea32e        NaN
# 24          129485553  not-logged-in-80bdc4acf6d39d1ea32e        NaN
# 25          129485578  not-logged-in-80bdc4acf6d39d1ea32e        NaN
# 26          129485596  not-logged-in-80bdc4acf6d39d1ea32e        NaN
#
#                  user_ip  workflow_id workflow_name  workflow_version  \
# 13  ece34b7062ff27190425         8073  Full dataset             13.11
# 23  80bdc4acf6d39d1ea32e         8073  Full dataset             13.11
# 24  80bdc4acf6d39d1ea32e         8073  Full dataset             13.11
# 25  80bdc4acf6d39d1ea32e         8073  Full dataset             13.11
# 26  80bdc4acf6d39d1ea32e         8073  Full dataset             13.11
#
#                  created_at  gold_standard  expert  \
# 13  2018-10-28 10:00:31 UTC            NaN     NaN
# 23  2018-11-01 08:15:14 UTC            NaN     NaN
# 24  2018-11-01 08:16:38 UTC            NaN     NaN
# 25  2018-11-01 08:16:53 UTC            NaN     NaN
# 26  2018-11-01 08:17:11 UTC            NaN     NaN
#
#                                              metadata  \
# 13  {'source': 'api', 'session': '72e7236d3736b33e...
# 23  {'source': 'api', 'session': '3cf8bb39dc9ac314...
# 24  {'source': 'api', 'session': '3cf8bb39dc9ac314...
# 25  {'source': 'api', 'session': '3cf8bb39dc9ac314...
# 26  {'source': 'api', 'session': '3cf8bb39dc9ac314...
#
#                                           annotations  \
# 13  {'task': 'T0', 'task_label': 'Draw bounding bo...
# 23  {'task': 'T0', 'task_label': 'Draw bounding bo...
# 24  {'task': 'T0', 'task_label': 'Draw bounding bo...
# 25  {'task': 'T0', 'task_label': 'Draw bounding bo...
# 26  {'task': 'T0', 'task_label': 'Draw bounding bo...
#
#                                          subject_data  subject_ids  \
# 13  {'26976410': {'retired': None, 'fn': '/project...     26976410
# 23  {'27144341': {'retired': {'id': 24673754, 'wor...     27144341
# 24  {'27146358': {'retired': {'id': 24675851, 'wor...     27146358
# 25  {'27161730': {'retired': {'id': 24706423, 'wor...     27161730
# 26  {'27139667': {'retired': {'id': 24666988, 'wor...     27139667
#
#               datetime
# 13 2018-10-28 10:00:31
# 23 2018-11-01 08:15:14
# 24 2018-11-01 08:16:38
# 25 2018-11-01 08:16:53
# 26 2018-11-01 08:17:11

# %%
annos_full = annos_from_df(clas_full, img_size)

# %%
subjects_full = list(annos_full.keys()); len(subjects_full)
# Out:
# 9751

# %%
# Initialize IoU dict for every possible pairing of users
IoU_pairs = {}
for pair in product(np.unique(clas_full.user_name),repeat=2):
    IoU_pairs[pair[0]+'->'+pair[1]] = [0, 0]

# %%
annos_df = pd.DataFrame(data=None,columns=['subject_id','user','x','y','w','h','label'])

ind = 0
for key,values in annos_full.items():
    for value in values:
        annos_df.loc[ind,:] = [key,value[0],value[1][0],value[1][1],value[1][2],value[1][3],value[2]]
        ind+=1

# %%
verbose=False
# Loop over images
for subject_id, subj_df in tqdm(annos_df.groupby('subject_id')):
    # Disregard images that have been classified by one person only
    if len(np.unique(subj_df.user)) <= 1:
        continue
    # Loop over classes indentified within image
    classes_identified = np.unique(subj_df.label[subj_df.label.values != None])
    # Exclude 'None' classifications
    classes_identified_uniq = np.unique(classes_identified[classes_identified != None])
    for class_, class_df in subj_df.groupby('label'):
        # Combine user labels of one class to a filled array
        user_boxes = {}
        for user, user_df in class_df.groupby('user'):
            arr1 = iou.fill_array_with_boxes(user_df.iloc[:,2:6].values, (1500,1500))
            user_boxes[user] = arr1
        # Calculate IoU among the users having classified this image and with this class
        # NOTE: Currently the whole union and intersection is used, even if there was partly no overlap
        for user_combinations in product(user_boxes.keys(),repeat=2):
            user1, user2 = user_combinations
            if verbose:
                plt.imshow(user_boxes[user1]*2+user_boxes[user2]*1,cmap='Blues')
                plt.title('subject:{}, intersection of {} with {} for class {}'.format(subject_id, user1,user2,class_))
                plt.show()
                plt.close()
            union = np.count_nonzero(np.logical_or(user_boxes[user1],user_boxes[user2]))
            intersection = np.count_nonzero(np.logical_and(user_boxes[user1],user_boxes[user2]))
            try:
                IoU_pairs[user1+'->'+user2] = [IoU_pairs[user1+'->'+user2][0]+intersection/union, IoU_pairs[user1+'->'+user2][1]+1]
            except ZeroDivisionError:
                continue
# Out:
# HBox(children=(IntProgress(value=0, max=9751), HTML(value='')))

# %%
IoU_pairs
# Out:
# {'Armin.haghshenas->Armin.haghshenas': [517.0, 517],
#  'Armin.haghshenas->CKauhs': [3.422095135469926, 10],
#  'Armin.haghshenas->CStephan': [2.0308942760936954, 9],
#  'Armin.haghshenas->DelaS': [4.080336902430677, 11],
#  'Armin.haghshenas->JuleR': [3.9663409134733367, 8],
#  'Armin.haghshenas->Julia.Windmiller': [6.226449652857044, 15],
#  'Armin.haghshenas->LWMPI': [2.382417334102316, 12],
#  'Armin.haghshenas->MarcusKlingebiel': [4.575302315757874, 10],
#  'Armin.haghshenas->ReinhardB': [2.414140197165296, 6],
#  'Armin.haghshenas->Saybot': [3.05237860165139, 9],
#  'Armin.haghshenas->Serikov': [10.3738683062021, 20],
#  'Armin.haghshenas->ShCu': [4.436932431482912, 12],
#  'Armin.haghshenas->TobiasBecker': [7.986553528598509, 16],
#  'Armin.haghshenas->Uthlande': [4.289603265501083, 12],
#  'Armin.haghshenas->Wolkengebilde': [0.24346590627346928, 3],
#  'Armin.haghshenas->akio': [1.9511293133469705, 7],
#  'Armin.haghshenas->anna.luebke': [2.709883746256872, 5],
#  'Armin.haghshenas->biancorosa': [5.574283664275553, 15],
#  'Armin.haghshenas->bjorn.stevens': [9.344670959562597, 16],
#  'Armin.haghshenas->bkirsch': [1.025933328040768, 3],
#  'Armin.haghshenas->bko_cloud': [4.029801443215012, 11],
#  'Armin.haghshenas->bschul': [5.0545372923517204, 11],
#  'Armin.haghshenas->cathyhohenegger': [10.725370059892752, 27],
#  'Armin.haghshenas->christopher.moseley': [4.6117404263670165, 13],
#  'Armin.haghshenas->dleutwyler': [3.079270620834839, 11],
#  'Armin.haghshenas->double_p': [0.339506712252455, 1],
#  'Armin.haghshenas->elessar.telkontar': [8.474347463658495, 18],
#  'Armin.haghshenas->geetgeorge': [2.7069355812532767, 9],
#  'Armin.haghshenas->guidocioni': [8.610646940470982, 20],
#  'Armin.haghshenas->hartmut.borth': [7.670874643446354, 20],
#  'Armin.haghshenas->heikekonow': [2.3140869876636, 9],
#  'Armin.haghshenas->jan.welss': [11.766599912249141, 26],
#  'Armin.haghshenas->jkiliani': [8.819257716342772, 20],
#  'Armin.haghshenas->jpmellado': [5.81004023643289, 17],
#  'Armin.haghshenas->jvmpi': [5.459235383910905, 10],
#  'Armin.haghshenas->kfodor': [0.9270964354519877, 2],
#  'Armin.haghshenas->lkluft': [2.87896472835236, 6],
#  'Armin.haghshenas->lpaccini': [7.305137503163816, 19],
#  'Armin.haghshenas->lutz.hirsch': [8.435703310761356, 21],
#  'Armin.haghshenas->magio': [6.155377202238224, 14],
#  'Armin.haghshenas->majomi': [6.113380297054468, 14],
#  'Armin.haghshenas->monika.esch': [4.5509870126491725, 14],
#  'Armin.haghshenas->not-logged-in-0baa7228b5be68fb8e1a': [0.7895929896725375,
#   2],
#  'Armin.haghshenas->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'Armin.haghshenas->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'Armin.haghshenas->onnoq': [5.559562248128612, 11],
#  'Armin.haghshenas->raspstephan': [0, 0],
#  'Armin.haghshenas->tmieslinger': [1.655609865886868, 4],
#  'Armin.haghshenas->traute.crueger': [5.497802262816687, 16],
#  'CKauhs->Armin.haghshenas': [3.422095135469926, 10],
#  'CKauhs->CKauhs': [285.0, 285],
#  'CKauhs->CStephan': [3.2514417500321837, 9],
#  'CKauhs->DelaS': [2.874896157379232, 7],
#  'CKauhs->JuleR': [1.0331199155369377, 3],
#  'CKauhs->Julia.Windmiller': [3.0078037501351313, 7],
#  'CKauhs->LWMPI': [2.1979962270980886, 5],
#  'CKauhs->MarcusKlingebiel': [4.801354754911302, 8],
#  'CKauhs->ReinhardB': [2.759497741891708, 7],
#  'CKauhs->Saybot': [9.478574584744386, 21],
#  'CKauhs->Serikov': [4.5926345213147926, 8],
#  'CKauhs->ShCu': [4.228146375607926, 9],
#  'CKauhs->TobiasBecker': [5.12829242584846, 11],
#  'CKauhs->Uthlande': [4.184802144456164, 11],
#  'CKauhs->Wolkengebilde': [1.7347719642616308, 4],
#  'CKauhs->akio': [0.4669045175581206, 1],
#  'CKauhs->anna.luebke': [2.1991922382138576, 5],
#  'CKauhs->biancorosa': [3.990931483159426, 11],
#  'CKauhs->bjorn.stevens': [2.3371708091465573, 6],
#  'CKauhs->bkirsch': [1.2449940039616503, 3],
#  'CKauhs->bko_cloud': [2.1414605628416457, 4],
#  'CKauhs->bschul': [6.9023241920422915, 14],
#  'CKauhs->cathyhohenegger': [6.315051214048076, 13],
#  'CKauhs->christopher.moseley': [0.6640054239846693, 2],
#  'CKauhs->dleutwyler': [2.7359527545260893, 6],
#  'CKauhs->double_p': [2.225891774605037, 4],
#  'CKauhs->elessar.telkontar': [3.1555236692830677, 9],
#  'CKauhs->geetgeorge': [3.3600486467870843, 6],
#  'CKauhs->guidocioni': [5.792548559896963, 14],
#  'CKauhs->hartmut.borth': [4.417228545164505, 9],
#  'CKauhs->heikekonow': [2.5794763667939313, 8],
#  'CKauhs->jan.welss': [8.33431657393251, 19],
#  'CKauhs->jkiliani': [7.036009537724561, 16],
#  'CKauhs->jpmellado': [2.5448982041384682, 6],
#  'CKauhs->jvmpi': [0.9498949357188547, 2],
#  'CKauhs->kfodor': [0.8829908691876023, 2],
#  'CKauhs->lkluft': [0.242643630878925, 1],
#  'CKauhs->lpaccini': [7.354829246472383, 14],
#  'CKauhs->lutz.hirsch': [4.261258438225035, 8],
#  'CKauhs->magio': [3.479632988719662, 6],
#  'CKauhs->majomi': [5.770511002391132, 10],
#  'CKauhs->monika.esch': [1.5370367642552603, 4],
#  'CKauhs->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'CKauhs->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'CKauhs->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'CKauhs->onnoq': [3.8472819202929744, 10],
#  'CKauhs->raspstephan': [0.5405061870381951, 1],
#  'CKauhs->tmieslinger': [0, 0],
#  'CKauhs->traute.crueger': [3.182575559737371, 6],
#  'CStephan->Armin.haghshenas': [2.0308942760936954, 9],
#  'CStephan->CKauhs': [3.2514417500321837, 9],
#  'CStephan->CStephan': [235.0, 235],
#  'CStephan->DelaS': [2.4232061703129055, 10],
#  'CStephan->JuleR': [2.9525630949728017, 6],
#  'CStephan->Julia.Windmiller': [1.830636878573424, 5],
#  'CStephan->LWMPI': [1.4333892279739673, 4],
#  'CStephan->MarcusKlingebiel': [1.8808404677921624, 6],
#  'CStephan->ReinhardB': [0.41546139543986693, 4],
#  'CStephan->Saybot': [2.606045380519854, 6],
#  'CStephan->Serikov': [3.768190761736954, 9],
#  'CStephan->ShCu': [3.0211455824454982, 6],
#  'CStephan->TobiasBecker': [3.709592460452191, 12],
#  'CStephan->Uthlande': [5.3374736879083, 11],
#  'CStephan->Wolkengebilde': [2.5866926401362096, 7],
#  'CStephan->akio': [0, 0],
#  'CStephan->anna.luebke': [3.050183225019209, 7],
#  'CStephan->biancorosa': [0.0, 1],
#  'CStephan->bjorn.stevens': [4.211780875456867, 9],
#  'CStephan->bkirsch': [0.5419341817364487, 1],
#  'CStephan->bko_cloud': [2.902376249468031, 6],
#  'CStephan->bschul': [4.38030000741887, 11],
#  'CStephan->cathyhohenegger': [5.137052154449931, 14],
#  'CStephan->christopher.moseley': [1.7457223919779825, 5],
#  'CStephan->dleutwyler': [3.160728743653614, 7],
#  'CStephan->double_p': [0.7561492206446396, 4],
#  'CStephan->elessar.telkontar': [0.6995942215526703, 4],
#  'CStephan->geetgeorge': [1.2920790877298816, 5],
#  'CStephan->guidocioni': [10.080681920116316, 22],
#  'CStephan->hartmut.borth': [3.2983706982040943, 8],
#  'CStephan->heikekonow': [3.065500416623544, 10],
#  'CStephan->jan.welss': [9.50243958284676, 26],
#  'CStephan->jkiliani': [5.922521449283935, 16],
#  'CStephan->jpmellado': [6.254501582278435, 15],
#  'CStephan->jvmpi': [0.6966021574666539, 3],
#  'CStephan->kfodor': [1.6226145554106328, 4],
#  'CStephan->lkluft': [0.7157772054977207, 1],
#  'CStephan->lpaccini': [6.4500794864701385, 11],
#  'CStephan->lutz.hirsch': [4.945494473571699, 11],
#  'CStephan->magio': [3.80098367963637, 7],
#  'CStephan->majomi': [5.058576991478498, 14],
#  'CStephan->monika.esch': [2.048568133071445, 4],
#  'CStephan->not-logged-in-0baa7228b5be68fb8e1a': [0.48732535117433445, 1],
#  'CStephan->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'CStephan->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'CStephan->onnoq': [3.89487379865919, 12],
#  'CStephan->raspstephan': [1.265776723441557, 4],
#  'CStephan->tmieslinger': [0.7532449175699256, 2],
#  'CStephan->traute.crueger': [3.1894319940098477, 7],
#  'DelaS->Armin.haghshenas': [4.080336902430677, 11],
#  'DelaS->CKauhs': [2.874896157379232, 7],
#  'DelaS->CStephan': [2.4232061703129055, 10],
#  'DelaS->DelaS': [349.0, 349],
#  'DelaS->JuleR': [3.751744326473235, 7],
#  'DelaS->Julia.Windmiller': [3.372429582499954, 12],
#  'DelaS->LWMPI': [3.217773567645275, 12],
#  'DelaS->MarcusKlingebiel': [1.3908871659666102, 5],
#  'DelaS->ReinhardB': [1.3723656611648358, 4],
#  'DelaS->Saybot': [4.128897744224124, 8],
#  'DelaS->Serikov': [4.312607569420268, 14],
#  'DelaS->ShCu': [4.874601830421443, 12],
#  'DelaS->TobiasBecker': [2.698484523551439, 8],
#  'DelaS->Uthlande': [3.596058328487336, 11],
#  'DelaS->Wolkengebilde': [1.5547695338792082, 4],
#  'DelaS->akio': [1.30097273093684, 4],
#  'DelaS->anna.luebke': [1.1440989156316899, 4],
#  'DelaS->biancorosa': [1.9781560041519082, 8],
#  'DelaS->bjorn.stevens': [3.5814955700192743, 10],
#  'DelaS->bkirsch': [1.3180869377804183, 3],
#  'DelaS->bko_cloud': [1.7006408602592682, 5],
#  'DelaS->bschul': [4.172388336889725, 10],
#  'DelaS->cathyhohenegger': [3.540645887494274, 12],
#  'DelaS->christopher.moseley': [2.7443551039260816, 8],
#  'DelaS->dleutwyler': [1.5255768081920782, 4],
#  'DelaS->double_p': [0.6941861290678382, 2],
#  'DelaS->elessar.telkontar': [2.686753873030694, 10],
#  'DelaS->geetgeorge': [5.9380845425662026, 12],
#  'DelaS->guidocioni': [4.475442900190256, 13],
#  'DelaS->hartmut.borth': [2.76764920443575, 9],
#  'DelaS->heikekonow': [2.9474276360378346, 6],
#  'DelaS->jan.welss': [5.045484525135084, 15],
#  'DelaS->jkiliani': [1.3698925716382493, 5],
#  'DelaS->jpmellado': [1.9102167411505095, 5],
#  'DelaS->jvmpi': [2.0337781804419137, 6],
#  'DelaS->kfodor': [0.9447163034063913, 2],
#  'DelaS->lkluft': [1.2551568546905518, 2],
#  'DelaS->lpaccini': [6.367529167158549, 15],
#  'DelaS->lutz.hirsch': [5.206948628505006, 11],
#  'DelaS->magio': [5.800282760631487, 15],
#  'DelaS->majomi': [6.828618199698153, 14],
#  'DelaS->monika.esch': [3.667886155468518, 10],
#  'DelaS->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'DelaS->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'DelaS->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'DelaS->onnoq': [3.224096043608906, 10],
#  'DelaS->raspstephan': [0.0, 1],
#  'DelaS->tmieslinger': [0, 0],
#  'DelaS->traute.crueger': [4.281529852539839, 11],
#  'JuleR->Armin.haghshenas': [3.9663409134733367, 8],
#  'JuleR->CKauhs': [1.0331199155369377, 3],
#  'JuleR->CStephan': [2.9525630949728017, 6],
#  'JuleR->DelaS': [3.751744326473235, 7],
#  'JuleR->JuleR': [358.0, 358],
#  'JuleR->Julia.Windmiller': [6.744953590573596, 16],
#  'JuleR->LWMPI': [5.2638969606259565, 10],
#  'JuleR->MarcusKlingebiel': [3.342393086246093, 6],
#  'JuleR->ReinhardB': [1.7780025900615928, 3],
#  'JuleR->Saybot': [3.2971459888965566, 7],
#  'JuleR->Serikov': [11.797754902944531, 28],
#  'JuleR->ShCu': [8.017736484439183, 17],
#  'JuleR->TobiasBecker': [5.808148214600878, 16],
#  'JuleR->Uthlande': [6.492206728115893, 14],
#  'JuleR->Wolkengebilde': [2.9970683357571706, 8],
#  'JuleR->akio': [0.6955440348625667, 3],
#  'JuleR->anna.luebke': [3.810022289860618, 10],
#  'JuleR->biancorosa': [5.1637528596712015, 9],
#  'JuleR->bjorn.stevens': [8.866600383134958, 20],
#  'JuleR->bkirsch': [0.46668945853124366, 1],
#  'JuleR->bko_cloud': [4.3190266878376695, 9],
#  'JuleR->bschul': [5.095711445431456, 11],
#  'JuleR->cathyhohenegger': [8.55121796980649, 18],
#  'JuleR->christopher.moseley': [3.8769902823835762, 8],
#  'JuleR->dleutwyler': [7.176676313343535, 15],
#  'JuleR->double_p': [0.6328569200402795, 2],
#  'JuleR->elessar.telkontar': [1.3053253276952925, 4],
#  'JuleR->geetgeorge': [2.6301694558624344, 5],
#  'JuleR->guidocioni': [8.3087387468772, 23],
#  'JuleR->hartmut.borth': [4.014284811385565, 12],
#  'JuleR->heikekonow': [0.31877576411641606, 2],
#  'JuleR->jan.welss': [15.07750436274108, 32],
#  'JuleR->jkiliani': [2.4656324022506224, 8],
#  'JuleR->jpmellado': [4.37333431301231, 8],
#  'JuleR->jvmpi': [1.4673966085972157, 3],
#  'JuleR->kfodor': [1.117667877108257, 3],
#  'JuleR->lkluft': [0.9045826196137283, 3],
#  'JuleR->lpaccini': [11.293920214859964, 24],
#  'JuleR->lutz.hirsch': [5.569022156623135, 12],
#  'JuleR->magio': [8.828192588031984, 17],
#  'JuleR->majomi': [5.9646384058384, 14],
#  'JuleR->monika.esch': [2.8128340672155208, 10],
#  'JuleR->not-logged-in-0baa7228b5be68fb8e1a': [2.065956358463077, 4],
#  'JuleR->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'JuleR->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'JuleR->onnoq': [7.201059788988335, 13],
#  'JuleR->raspstephan': [0.12374814882063562, 1],
#  'JuleR->tmieslinger': [2.7370581192806993, 5],
#  'JuleR->traute.crueger': [4.575045168915413, 12],
#  'Julia.Windmiller->Armin.haghshenas': [6.226449652857044, 15],
#  'Julia.Windmiller->CKauhs': [3.0078037501351313, 7],
#  'Julia.Windmiller->CStephan': [1.830636878573424, 5],
#  'Julia.Windmiller->DelaS': [3.372429582499954, 12],
#  'Julia.Windmiller->JuleR': [6.744953590573596, 16],
#  'Julia.Windmiller->Julia.Windmiller': [427.0, 427],
#  'Julia.Windmiller->LWMPI': [2.452724328902126, 6],
#  'Julia.Windmiller->MarcusKlingebiel': [2.638814318677849, 5],
#  'Julia.Windmiller->ReinhardB': [3.394855641332411, 13],
#  'Julia.Windmiller->Saybot': [8.562564195301754, 23],
#  'Julia.Windmiller->Serikov': [5.2434625483085755, 12],
#  'Julia.Windmiller->ShCu': [7.3892974655794275, 18],
#  'Julia.Windmiller->TobiasBecker': [1.397321212264352, 7],
#  'Julia.Windmiller->Uthlande': [3.93575638536361, 11],
#  'Julia.Windmiller->Wolkengebilde': [1.2371557014383914, 4],
#  'Julia.Windmiller->akio': [0.2908982312783521, 4],
#  'Julia.Windmiller->anna.luebke': [3.3879447413214754, 8],
#  'Julia.Windmiller->biancorosa': [1.6282930007278953, 3],
#  'Julia.Windmiller->bjorn.stevens': [3.808070083132001, 10],
#  'Julia.Windmiller->bkirsch': [1.4447076115889013, 4],
#  'Julia.Windmiller->bko_cloud': [2.6091874305735603, 9],
#  'Julia.Windmiller->bschul': [9.272506121341618, 20],
#  'Julia.Windmiller->cathyhohenegger': [8.199443001669836, 17],
#  'Julia.Windmiller->christopher.moseley': [3.11592289823212, 8],
#  'Julia.Windmiller->dleutwyler': [3.855289080505447, 10],
#  'Julia.Windmiller->double_p': [1.6513739946926673, 4],
#  'Julia.Windmiller->elessar.telkontar': [5.101005143859428, 11],
#  'Julia.Windmiller->geetgeorge': [9.233058548362846, 16],
#  'Julia.Windmiller->guidocioni': [10.265176700686796, 21],
#  'Julia.Windmiller->hartmut.borth': [3.6692650897875962, 11],
#  'Julia.Windmiller->heikekonow': [1.0954966573548361, 3],
#  'Julia.Windmiller->jan.welss': [9.38729825538021, 22],
#  'Julia.Windmiller->jkiliani': [4.956765609102573, 10],
#  'Julia.Windmiller->jpmellado': [7.439519077655784, 13],
#  'Julia.Windmiller->jvmpi': [2.930494734445444, 7],
#  'Julia.Windmiller->kfodor': [1.6106981913643161, 5],
#  'Julia.Windmiller->lkluft': [0, 0],
#  'Julia.Windmiller->lpaccini': [4.8181638393164805, 9],
#  'Julia.Windmiller->lutz.hirsch': [6.631955730136167, 12],
#  'Julia.Windmiller->magio': [1.6432723000694838, 6],
#  'Julia.Windmiller->majomi': [5.8167441366202555, 16],
#  'Julia.Windmiller->monika.esch': [2.4186276584579858, 8],
#  'Julia.Windmiller->not-logged-in-0baa7228b5be68fb8e1a': [0.29557024835994794,
#   1],
#  'Julia.Windmiller->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'Julia.Windmiller->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'Julia.Windmiller->onnoq': [7.0695857238988635, 18],
#  'Julia.Windmiller->raspstephan': [2.6036638191438723, 5],
#  'Julia.Windmiller->tmieslinger': [1.3543202739758387, 2],
#  'Julia.Windmiller->traute.crueger': [3.949519743234344, 9],
#  'LWMPI->Armin.haghshenas': [2.382417334102316, 12],
#  'LWMPI->CKauhs': [2.1979962270980886, 5],
#  'LWMPI->CStephan': [1.4333892279739673, 4],
#  'LWMPI->DelaS': [3.217773567645275, 12],
#  'LWMPI->JuleR': [5.2638969606259565, 10],
#  'LWMPI->Julia.Windmiller': [2.452724328902126, 6],
#  'LWMPI->LWMPI': [352.0, 352],
#  'LWMPI->MarcusKlingebiel': [1.984442829514879, 4],
#  'LWMPI->ReinhardB': [1.5091426181667393, 5],
#  'LWMPI->Saybot': [3.6980845158102342, 10],
#  'LWMPI->Serikov': [8.445732165400281, 20],
#  'LWMPI->ShCu': [5.050485024970677, 14],
#  'LWMPI->TobiasBecker': [3.548898629428764, 10],
#  'LWMPI->Uthlande': [2.5855784874206793, 10],
#  'LWMPI->Wolkengebilde': [2.6387600443296573, 7],
#  'LWMPI->akio': [1.151630441281089, 3],
#  'LWMPI->anna.luebke': [3.336227328213191, 8],
#  'LWMPI->biancorosa': [2.7171715799012888, 7],
#  'LWMPI->bjorn.stevens': [6.1004755908692365, 13],
#  'LWMPI->bkirsch': [0.576465541640133, 1],
#  'LWMPI->bko_cloud': [5.4870480318114865, 13],
#  'LWMPI->bschul': [3.3624137554862727, 11],
#  'LWMPI->cathyhohenegger': [9.91371653086407, 23],
#  'LWMPI->christopher.moseley': [4.589741408900095, 10],
#  'LWMPI->dleutwyler': [5.476874494007577, 15],
#  'LWMPI->double_p': [1.9129940981934281, 4],
#  'LWMPI->elessar.telkontar': [5.896824216038628, 15],
#  'LWMPI->geetgeorge': [3.3097607731590033, 8],
#  'LWMPI->guidocioni': [14.313985122686395, 24],
#  'LWMPI->hartmut.borth': [3.016122197806255, 10],
#  'LWMPI->heikekonow': [3.583896047063819, 8],
#  'LWMPI->jan.welss': [12.150780499536753, 29],
#  'LWMPI->jkiliani': [8.005208922953129, 14],
#  'LWMPI->jpmellado': [8.46543341064263, 20],
#  'LWMPI->jvmpi': [2.588863252211761, 5],
#  'LWMPI->kfodor': [2.106177477650343, 4],
#  'LWMPI->lkluft': [0.7493411144578314, 2],
#  'LWMPI->lpaccini': [11.49068967204213, 21],
#  'LWMPI->lutz.hirsch': [6.032381950037464, 13],
#  'LWMPI->magio': [7.6069636194689325, 14],
#  'LWMPI->majomi': [7.901431212595771, 20],
#  'LWMPI->monika.esch': [3.8658446591900417, 10],
#  'LWMPI->not-logged-in-0baa7228b5be68fb8e1a': [1.1315361979674723, 2],
#  'LWMPI->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'LWMPI->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'LWMPI->onnoq': [5.142585650156792, 12],
#  'LWMPI->raspstephan': [0.578263123424198, 2],
#  'LWMPI->tmieslinger': [0, 0],
#  'LWMPI->traute.crueger': [4.539941956921561, 10],
#  'MarcusKlingebiel->Armin.haghshenas': [4.575302315757874, 10],
#  'MarcusKlingebiel->CKauhs': [4.801354754911302, 8],
#  'MarcusKlingebiel->CStephan': [1.8808404677921624, 6],
#  'MarcusKlingebiel->DelaS': [1.3908871659666102, 5],
#  'MarcusKlingebiel->JuleR': [3.342393086246093, 6],
#  'MarcusKlingebiel->Julia.Windmiller': [2.638814318677849, 5],
#  'MarcusKlingebiel->LWMPI': [1.984442829514879, 4],
#  'MarcusKlingebiel->MarcusKlingebiel': [360.0, 360],
#  'MarcusKlingebiel->ReinhardB': [2.5611965003719623, 11],
#  'MarcusKlingebiel->Saybot': [2.1573315433573015, 4],
#  'MarcusKlingebiel->Serikov': [7.552395180055579, 15],
#  'MarcusKlingebiel->ShCu': [4.175065325766307, 9],
#  'MarcusKlingebiel->TobiasBecker': [1.5917611629598385, 8],
#  'MarcusKlingebiel->Uthlande': [1.988820565234286, 5],
#  'MarcusKlingebiel->Wolkengebilde': [2.530633645874302, 6],
#  'MarcusKlingebiel->akio': [0.9234793616191339, 2],
#  'MarcusKlingebiel->anna.luebke': [0.5611986102608544, 1],
#  'MarcusKlingebiel->biancorosa': [2.478080468004159, 6],
#  'MarcusKlingebiel->bjorn.stevens': [3.329471810023425, 7],
#  'MarcusKlingebiel->bkirsch': [1.0031819590955497, 4],
#  'MarcusKlingebiel->bko_cloud': [3.4365110684228757, 7],
#  'MarcusKlingebiel->bschul': [1.9815607973526144, 4],
#  'MarcusKlingebiel->cathyhohenegger': [3.830289076954496, 7],
#  'MarcusKlingebiel->christopher.moseley': [1.4293794598287908, 2],
#  'MarcusKlingebiel->dleutwyler': [3.4978915531104, 6],
#  'MarcusKlingebiel->double_p': [1.8324790242139217, 4],
#  'MarcusKlingebiel->elessar.telkontar': [5.654974380376751, 13],
#  'MarcusKlingebiel->geetgeorge': [1.0436545788082363, 2],
#  'MarcusKlingebiel->guidocioni': [7.9858585605739085, 20],
#  'MarcusKlingebiel->hartmut.borth': [4.299362655119174, 10],
#  'MarcusKlingebiel->heikekonow': [2.6531483628344517, 6],
#  'MarcusKlingebiel->jan.welss': [10.522855989407063, 21],
#  'MarcusKlingebiel->jkiliani': [1.7930697050022053, 5],
#  'MarcusKlingebiel->jpmellado': [4.76129698282423, 11],
#  'MarcusKlingebiel->jvmpi': [1.1585183535739345, 4],
#  'MarcusKlingebiel->kfodor': [1.6759255657673329, 4],
#  'MarcusKlingebiel->lkluft': [1.3569920192142901, 2],
#  'MarcusKlingebiel->lpaccini': [2.5838364553593354, 7],
#  'MarcusKlingebiel->lutz.hirsch': [1.290875201576089, 3],
#  'MarcusKlingebiel->magio': [4.813925354296719, 12],
#  'MarcusKlingebiel->majomi': [3.8125864923451376, 10],
#  'MarcusKlingebiel->monika.esch': [0.4441289052820141, 2],
#  'MarcusKlingebiel->not-logged-in-0baa7228b5be68fb8e1a': [1.7442681858856917,
#   4],
#  'MarcusKlingebiel->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'MarcusKlingebiel->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'MarcusKlingebiel->onnoq': [7.17980889827201, 19],
#  'MarcusKlingebiel->raspstephan': [0.7577959833882468, 1],
#  'MarcusKlingebiel->tmieslinger': [4.377129635146293, 8],
#  'MarcusKlingebiel->traute.crueger': [5.857165383229157, 14],
#  'ReinhardB->Armin.haghshenas': [2.414140197165296, 6],
#  'ReinhardB->CKauhs': [2.759497741891708, 7],
#  'ReinhardB->CStephan': [0.41546139543986693, 4],
#  'ReinhardB->DelaS': [1.3723656611648358, 4],
#  'ReinhardB->JuleR': [1.7780025900615928, 3],
#  'ReinhardB->Julia.Windmiller': [3.394855641332411, 13],
#  'ReinhardB->LWMPI': [1.5091426181667393, 5],
#  'ReinhardB->MarcusKlingebiel': [2.5611965003719623, 11],
#  'ReinhardB->ReinhardB': [341.0, 341],
#  'ReinhardB->Saybot': [4.33186480836449, 10],
#  'ReinhardB->Serikov': [2.7644475269897235, 11],
#  'ReinhardB->ShCu': [3.0691458718960427, 10],
#  'ReinhardB->TobiasBecker': [4.1697656252024125, 13],
#  'ReinhardB->Uthlande': [3.053908070663015, 12],
#  'ReinhardB->Wolkengebilde': [0.8358043039837644, 2],
#  'ReinhardB->akio': [0.4565433160474349, 1],
#  'ReinhardB->anna.luebke': [3.7777213623275094, 10],
#  'ReinhardB->biancorosa': [2.899508570153049, 14],
#  'ReinhardB->bjorn.stevens': [4.1840892084742345, 12],
#  'ReinhardB->bkirsch': [0.07299013257848358, 2],
#  'ReinhardB->bko_cloud': [0.9037375581600801, 2],
#  'ReinhardB->bschul': [2.0607309685269657, 4],
#  'ReinhardB->cathyhohenegger': [3.6239659287643566, 10],
#  'ReinhardB->christopher.moseley': [1.6162174075056777, 5],
#  'ReinhardB->dleutwyler': [3.320518783074945, 10],
#  'ReinhardB->double_p': [0, 0],
#  'ReinhardB->elessar.telkontar': [2.029413133423274, 9],
#  'ReinhardB->geetgeorge': [1.3032082732809809, 4],
#  'ReinhardB->guidocioni': [3.4429605306737434, 11],
#  'ReinhardB->hartmut.borth': [1.8670569744904855, 4],
#  'ReinhardB->heikekonow': [1.3425647182967053, 7],
#  'ReinhardB->jan.welss': [4.691678359286168, 16],
#  'ReinhardB->jkiliani': [5.4370772590084115, 23],
#  'ReinhardB->jpmellado': [1.7199010999901359, 9],
#  'ReinhardB->jvmpi': [2.9069069633983555, 6],
#  'ReinhardB->kfodor': [0.4373637110880112, 2],
#  'ReinhardB->lkluft': [2.390002129654384, 5],
#  'ReinhardB->lpaccini': [6.072857338182454, 18],
#  'ReinhardB->lutz.hirsch': [2.4800414699105593, 10],
#  'ReinhardB->magio': [3.7712082901277624, 9],
#  'ReinhardB->majomi': [2.4631519670842916, 14],
#  'ReinhardB->monika.esch': [2.309517612894086, 9],
#  'ReinhardB->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'ReinhardB->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'ReinhardB->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'ReinhardB->onnoq': [2.4573369489161427, 13],
#  'ReinhardB->raspstephan': [0, 0],
#  'ReinhardB->tmieslinger': [0.6677709676418511, 3],
#  'ReinhardB->traute.crueger': [1.471325022743796, 6],
#  'Saybot->Armin.haghshenas': [3.05237860165139, 9],
#  'Saybot->CKauhs': [9.478574584744386, 21],
#  'Saybot->CStephan': [2.606045380519854, 6],
#  'Saybot->DelaS': [4.128897744224124, 8],
#  'Saybot->JuleR': [3.2971459888965566, 7],
#  'Saybot->Julia.Windmiller': [8.562564195301754, 23],
#  'Saybot->LWMPI': [3.6980845158102342, 10],
#  'Saybot->MarcusKlingebiel': [2.1573315433573015, 4],
#  'Saybot->ReinhardB': [4.33186480836449, 10],
#  'Saybot->Saybot': [456.0, 456],
#  'Saybot->Serikov': [5.8052647813710765, 12],
#  'Saybot->ShCu': [3.6834480031034738, 9],
#  'Saybot->TobiasBecker': [4.40196679866153, 11],
#  'Saybot->Uthlande': [4.6021239595727526, 12],
#  'Saybot->Wolkengebilde': [3.6077637137340526, 8],
#  'Saybot->akio': [2.6964647349820012, 6],
#  'Saybot->anna.luebke': [4.1109694319863825, 12],
#  'Saybot->biancorosa': [3.90906741133681, 8],
#  'Saybot->bjorn.stevens': [2.7378764579268866, 7],
#  'Saybot->bkirsch': [1.1999231351683446, 2],
#  'Saybot->bko_cloud': [3.4938537956149123, 6],
#  'Saybot->bschul': [5.370387993089916, 12],
#  'Saybot->cathyhohenegger': [4.835784339090616, 9],
#  'Saybot->christopher.moseley': [2.3657822701157203, 5],
#  'Saybot->dleutwyler': [4.061878177855076, 11],
#  'Saybot->double_p': [1.334845014174936, 5],
#  'Saybot->elessar.telkontar': [3.2063239876834473, 9],
#  'Saybot->geetgeorge': [6.681627248843804, 15],
#  'Saybot->guidocioni': [7.774994102645048, 18],
#  'Saybot->hartmut.borth': [4.646283277915228, 12],
#  'Saybot->heikekonow': [2.227831235629658, 4],
#  'Saybot->jan.welss': [14.430025183987839, 35],
#  'Saybot->jkiliani': [5.740627348122088, 12],
#  'Saybot->jpmellado': [4.389523915113053, 9],
#  'Saybot->jvmpi': [2.9130640553624487, 5],
#  'Saybot->kfodor': [0.16129936407747553, 1],
#  'Saybot->lkluft': [2.314850622112065, 5],
#  'Saybot->lpaccini': [9.686405731242207, 20],
#  'Saybot->lutz.hirsch': [2.9701310409648674, 9],
#  'Saybot->magio': [4.9502997426273385, 9],
#  'Saybot->majomi': [6.9579494817655805, 15],
#  'Saybot->monika.esch': [2.39661987032932, 9],
#  'Saybot->not-logged-in-0baa7228b5be68fb8e1a': [0.8014724621194753, 2],
#  'Saybot->not-logged-in-50dab35d7f338290c5f2': [0.7170201718895463, 2],
#  'Saybot->not-logged-in-c9c96a955486304fe369': [0.1369241613392048, 1],
#  'Saybot->onnoq': [13.08357021826995, 27],
#  'Saybot->raspstephan': [2.8892410123079566, 5],
#  'Saybot->tmieslinger': [0, 0],
#  'Saybot->traute.crueger': [4.356536528119321, 10],
#  'Serikov->Armin.haghshenas': [10.3738683062021, 20],
#  'Serikov->CKauhs': [4.5926345213147926, 8],
#  'Serikov->CStephan': [3.768190761736954, 9],
#  'Serikov->DelaS': [4.312607569420268, 14],
#  'Serikov->JuleR': [11.797754902944531, 28],
#  'Serikov->Julia.Windmiller': [5.2434625483085755, 12],
#  'Serikov->LWMPI': [8.445732165400281, 20],
#  'Serikov->MarcusKlingebiel': [7.552395180055579, 15],
#  'Serikov->ReinhardB': [2.7644475269897235, 11],
#  'Serikov->Saybot': [5.8052647813710765, 12],
#  'Serikov->Serikov': [602.0, 602],
#  'Serikov->ShCu': [8.113040650867523, 19],
#  'Serikov->TobiasBecker': [6.0655279778841384, 20],
#  'Serikov->Uthlande': [5.301120133711281, 12],
#  'Serikov->Wolkengebilde': [1.6523974244094548, 5],
#  'Serikov->akio': [1.1607210750659174, 7],
#  'Serikov->anna.luebke': [1.3527763193950102, 5],
#  'Serikov->biancorosa': [8.934604582297716, 24],
#  'Serikov->bjorn.stevens': [9.476183504186423, 22],
#  'Serikov->bkirsch': [3.847152376481476, 8],
#  'Serikov->bko_cloud': [8.621485249763982, 17],
#  'Serikov->bschul': [2.0260155046657213, 5],
#  'Serikov->cathyhohenegger': [13.164388331339252, 30],
#  'Serikov->christopher.moseley': [6.353040351806305, 13],
#  'Serikov->dleutwyler': [8.33513748879903, 18],
#  'Serikov->double_p': [3.1523517940652965, 6],
#  'Serikov->elessar.telkontar': [5.84893290458113, 11],
#  'Serikov->geetgeorge': [4.3917051473186595, 9],
#  'Serikov->guidocioni': [15.426113070494655, 34],
#  'Serikov->hartmut.borth': [9.059732125525729, 25],
#  'Serikov->heikekonow': [3.476358883376295, 7],
#  'Serikov->jan.welss': [20.498622974702354, 47],
#  'Serikov->jkiliani': [9.206390196329783, 21],
#  'Serikov->jpmellado': [7.014388318931953, 16],
#  'Serikov->jvmpi': [2.7212575549201867, 9],
#  'Serikov->kfodor': [4.176505385207521, 9],
#  'Serikov->lkluft': [3.137600244779014, 7],
#  'Serikov->lpaccini': [8.281953550310694, 24],
#  'Serikov->lutz.hirsch': [10.78338636792203, 25],
#  'Serikov->magio': [12.288739398714425, 21],
#  'Serikov->majomi': [12.447443774138685, 23],
#  'Serikov->monika.esch': [5.119114852033597, 13],
#  'Serikov->not-logged-in-0baa7228b5be68fb8e1a': [2.1479252608087878, 4],
#  'Serikov->not-logged-in-50dab35d7f338290c5f2': [1.3590409275898425, 2],
#  'Serikov->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'Serikov->onnoq': [9.146330688110863, 21],
#  'Serikov->raspstephan': [0.9423739445276127, 2],
#  'Serikov->tmieslinger': [3.366025690514585, 6],
#  'Serikov->traute.crueger': [4.696315957767431, 13],
#  'ShCu->Armin.haghshenas': [4.436932431482912, 12],
#  'ShCu->CKauhs': [4.228146375607926, 9],
#  'ShCu->CStephan': [3.0211455824454982, 6],
#  'ShCu->DelaS': [4.874601830421443, 12],
#  'ShCu->JuleR': [8.017736484439183, 17],
#  'ShCu->Julia.Windmiller': [7.3892974655794275, 18],
#  'ShCu->LWMPI': [5.050485024970677, 14],
#  'ShCu->MarcusKlingebiel': [4.175065325766307, 9],
#  'ShCu->ReinhardB': [3.0691458718960427, 10],
#  'ShCu->Saybot': [3.6834480031034738, 9],
#  'ShCu->Serikov': [8.113040650867523, 19],
#  'ShCu->ShCu': [475.0, 475],
#  'ShCu->TobiasBecker': [6.164230950765731, 16],
#  'ShCu->Uthlande': [4.899070926956457, 12],
#  'ShCu->Wolkengebilde': [0.9114720848779774, 3],
#  'ShCu->akio': [3.4195130147988357, 9],
#  'ShCu->anna.luebke': [3.838150703076618, 8],
#  'ShCu->biancorosa': [3.3848153332595814, 9],
#  'ShCu->bjorn.stevens': [4.544701101553805, 11],
#  'ShCu->bkirsch': [2.655632803910786, 8],
#  'ShCu->bko_cloud': [3.5324760565366455, 8],
#  'ShCu->bschul': [6.904127819325137, 16],
#  'ShCu->cathyhohenegger': [6.025987037099852, 17],
#  'ShCu->christopher.moseley': [4.893182338735495, 12],
#  'ShCu->dleutwyler': [3.357052136029676, 10],
#  'ShCu->double_p': [3.16357750720012, 8],
#  'ShCu->elessar.telkontar': [3.172069633822624, 10],
#  'ShCu->geetgeorge': [6.418381797517232, 13],
#  'ShCu->guidocioni': [5.9962796951447634, 14],
#  'ShCu->hartmut.borth': [3.86905961266494, 13],
#  'ShCu->heikekonow': [5.750220038559006, 12],
#  'ShCu->jan.welss': [11.332968045281001, 26],
#  'ShCu->jkiliani': [10.135100717467914, 23],
#  'ShCu->jpmellado': [5.636766675446469, 12],
#  'ShCu->jvmpi': [2.363627314430933, 6],
#  'ShCu->kfodor': [2.2848272196911887, 6],
#  'ShCu->lkluft': [3.1823333586709563, 8],
#  'ShCu->lpaccini': [9.240502504911829, 20],
#  'ShCu->lutz.hirsch': [8.239868625395234, 17],
#  'ShCu->magio': [3.5867657358114924, 7],
#  'ShCu->majomi': [7.669926950149259, 19],
#  'ShCu->monika.esch': [4.8923701928241385, 14],
#  'ShCu->not-logged-in-0baa7228b5be68fb8e1a': [1.643034921091843, 3],
#  'ShCu->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'ShCu->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'ShCu->onnoq': [5.610785153485265, 13],
#  'ShCu->raspstephan': [2.003082832222568, 4],
#  'ShCu->tmieslinger': [0, 0],
#  'ShCu->traute.crueger': [3.84025862590333, 7],
#  'TobiasBecker->Armin.haghshenas': [7.986553528598509, 16],
#  'TobiasBecker->CKauhs': [5.12829242584846, 11],
#  'TobiasBecker->CStephan': [3.709592460452191, 12],
#  'TobiasBecker->DelaS': [2.698484523551439, 8],
#  'TobiasBecker->JuleR': [5.808148214600878, 16],
#  'TobiasBecker->Julia.Windmiller': [1.397321212264352, 7],
#  'TobiasBecker->LWMPI': [3.548898629428764, 10],
#  'TobiasBecker->MarcusKlingebiel': [1.5917611629598385, 8],
#  'TobiasBecker->ReinhardB': [4.1697656252024125, 13],
#  'TobiasBecker->Saybot': [4.40196679866153, 11],
#  'TobiasBecker->Serikov': [6.0655279778841384, 20],
#  'TobiasBecker->ShCu': [6.164230950765731, 16],
#  'TobiasBecker->TobiasBecker': [511.0, 511],
#  'TobiasBecker->Uthlande': [3.645936984753101, 8],
#  'TobiasBecker->Wolkengebilde': [1.6347973331283308, 4],
#  'TobiasBecker->akio': [3.994545114975436, 9],
#  'TobiasBecker->anna.luebke': [2.5873736204925426, 7],
#  'TobiasBecker->biancorosa': [4.794431383200843, 12],
#  'TobiasBecker->bjorn.stevens': [4.694277963402254, 11],
#  'TobiasBecker->bkirsch': [3.287579645261642, 9],
#  'TobiasBecker->bko_cloud': [1.819886196993425, 7],
#  'TobiasBecker->bschul': [10.144882225395449, 25],
#  'TobiasBecker->cathyhohenegger': [10.334088336827012, 21],
#  'TobiasBecker->christopher.moseley': [5.9159073892068115, 15],
#  'TobiasBecker->dleutwyler': [4.519336037872774, 13],
#  'TobiasBecker->double_p': [2.8902768374434173, 6],
#  'TobiasBecker->elessar.telkontar': [3.9313399609717514, 14],
#  'TobiasBecker->geetgeorge': [4.966148223962256, 13],
#  'TobiasBecker->guidocioni': [11.455635503907116, 22],
#  'TobiasBecker->hartmut.borth': [7.141689480305695, 17],
#  'TobiasBecker->heikekonow': [1.533980793712852, 6],
#  'TobiasBecker->jan.welss': [10.87347156628219, 28],
#  'TobiasBecker->jkiliani': [7.9165902513398505, 23],
#  'TobiasBecker->jpmellado': [10.457479857544493, 24],
#  'TobiasBecker->jvmpi': [3.842139954101234, 11],
#  'TobiasBecker->kfodor': [2.788003245766465, 5],
#  'TobiasBecker->lkluft': [1.8884315041284563, 4],
#  'TobiasBecker->lpaccini': [4.476818825918563, 17],
#  'TobiasBecker->lutz.hirsch': [3.963795128385994, 11],
#  'TobiasBecker->magio': [8.258473509718028, 18],
#  'TobiasBecker->majomi': [3.950829317382556, 10],
#  'TobiasBecker->monika.esch': [2.2959417376871403, 7],
#  'TobiasBecker->not-logged-in-0baa7228b5be68fb8e1a': [0.7294949825509188, 1],
#  'TobiasBecker->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'TobiasBecker->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'TobiasBecker->onnoq': [5.882362899182355, 20],
#  'TobiasBecker->raspstephan': [1.3647051700660762, 4],
#  'TobiasBecker->tmieslinger': [0.8277738261810266, 2],
#  'TobiasBecker->traute.crueger': [5.370172067056579, 12],
#  'Uthlande->Armin.haghshenas': [4.289603265501083, 12],
#  'Uthlande->CKauhs': [4.184802144456164, 11],
#  'Uthlande->CStephan': [5.3374736879083, 11],
#  'Uthlande->DelaS': [3.596058328487336, 11],
#  'Uthlande->JuleR': [6.492206728115893, 14],
#  'Uthlande->Julia.Windmiller': [3.93575638536361, 11],
#  'Uthlande->LWMPI': [2.5855784874206793, 10],
#  'Uthlande->MarcusKlingebiel': [1.988820565234286, 5],
#  'Uthlande->ReinhardB': [3.053908070663015, 12],
#  'Uthlande->Saybot': [4.6021239595727526, 12],
#  'Uthlande->Serikov': [5.301120133711281, 12],
#  'Uthlande->ShCu': [4.899070926956457, 12],
#  'Uthlande->TobiasBecker': [3.645936984753101, 8],
#  'Uthlande->Uthlande': [386.0, 386],
#  'Uthlande->Wolkengebilde': [1.0295586488189363, 4],
#  'Uthlande->akio': [1.66111144022994, 5],
#  'Uthlande->anna.luebke': [4.594247913088562, 9],
#  'Uthlande->biancorosa': [5.869581187513613, 15],
#  'Uthlande->bjorn.stevens': [4.473760123979149, 12],
#  'Uthlande->bkirsch': [1.7843322752706021, 5],
#  'Uthlande->bko_cloud': [1.5444880542977226, 4],
#  'Uthlande->bschul': [3.272781351584475, 9],
#  'Uthlande->cathyhohenegger': [7.353635040073418, 16],
#  'Uthlande->christopher.moseley': [3.0556861591461413, 8],
#  'Uthlande->dleutwyler': [4.8865530020957335, 9],
#  'Uthlande->double_p': [2.524322025041986, 8],
#  'Uthlande->elessar.telkontar': [6.126208109369497, 15],
#  'Uthlande->geetgeorge': [2.8380157452766963, 6],
#  'Uthlande->guidocioni': [11.853419684262013, 31],
#  'Uthlande->hartmut.borth': [4.25545532989845, 10],
#  'Uthlande->heikekonow': [1.4877026531799196, 6],
#  'Uthlande->jan.welss': [14.461722181107746, 40],
#  'Uthlande->jkiliani': [5.0172617407143445, 11],
#  'Uthlande->jpmellado': [5.577087383250258, 12],
#  'Uthlande->jvmpi': [3.318357991436117, 10],
#  'Uthlande->kfodor': [2.6348074895410636, 5],
#  'Uthlande->lkluft': [1.0402323317457216, 3],
#  'Uthlande->lpaccini': [6.349809893438951, 20],
#  'Uthlande->lutz.hirsch': [2.7706483992909283, 8],
#  'Uthlande->magio': [4.6177109782757135, 9],
#  'Uthlande->majomi': [4.439478407394416, 11],
#  'Uthlande->monika.esch': [5.277630891444297, 12],
#  'Uthlande->not-logged-in-0baa7228b5be68fb8e1a': [2.371742900541921, 5],
#  'Uthlande->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'Uthlande->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'Uthlande->onnoq': [4.723437590222022, 13],
#  'Uthlande->raspstephan': [0.6925695052849858, 1],
#  'Uthlande->tmieslinger': [0.5312388060764722, 2],
#  'Uthlande->traute.crueger': [4.956965893829985, 12],
#  'Wolkengebilde->Armin.haghshenas': [0.24346590627346928, 3],
#  'Wolkengebilde->CKauhs': [1.7347719642616308, 4],
#  'Wolkengebilde->CStephan': [2.5866926401362096, 7],
#  'Wolkengebilde->DelaS': [1.5547695338792082, 4],
#  'Wolkengebilde->JuleR': [2.9970683357571706, 8],
#  'Wolkengebilde->Julia.Windmiller': [1.2371557014383914, 4],
#  'Wolkengebilde->LWMPI': [2.6387600443296573, 7],
#  'Wolkengebilde->MarcusKlingebiel': [2.530633645874302, 6],
#  'Wolkengebilde->ReinhardB': [0.8358043039837644, 2],
#  'Wolkengebilde->Saybot': [3.6077637137340526, 8],
#  'Wolkengebilde->Serikov': [1.6523974244094548, 5],
#  'Wolkengebilde->ShCu': [0.9114720848779774, 3],
#  'Wolkengebilde->TobiasBecker': [1.6347973331283308, 4],
#  'Wolkengebilde->Uthlande': [1.0295586488189363, 4],
#  'Wolkengebilde->Wolkengebilde': [286.0, 286],
#  'Wolkengebilde->akio': [0.9810709551781207, 3],
#  'Wolkengebilde->anna.luebke': [0.25650638177996404, 1],
#  'Wolkengebilde->biancorosa': [2.534359826975601, 5],
#  'Wolkengebilde->bjorn.stevens': [4.375880678801648, 11],
#  'Wolkengebilde->bkirsch': [1.894944003693713, 4],
#  'Wolkengebilde->bko_cloud': [0.8087736151136727, 2],
#  'Wolkengebilde->bschul': [4.219110138802723, 9],
#  'Wolkengebilde->cathyhohenegger': [4.451177956304579, 12],
#  'Wolkengebilde->christopher.moseley': [0.3418055061558661, 2],
#  'Wolkengebilde->dleutwyler': [2.5767174108199806, 9],
#  'Wolkengebilde->double_p': [3.637013349770587, 6],
#  'Wolkengebilde->elessar.telkontar': [1.855379403289604, 7],
#  'Wolkengebilde->geetgeorge': [0.4636564415909494, 4],
#  'Wolkengebilde->guidocioni': [5.224437615914656, 19],
#  'Wolkengebilde->hartmut.borth': [2.1711839951788994, 6],
#  'Wolkengebilde->heikekonow': [0.7605202045778301, 5],
#  'Wolkengebilde->jan.welss': [6.086837549315647, 12],
#  'Wolkengebilde->jkiliani': [2.500713283031831, 10],
#  'Wolkengebilde->jpmellado': [2.4474872245793513, 8],
#  'Wolkengebilde->jvmpi': [1.1245825963391132, 4],
#  'Wolkengebilde->kfodor': [0.48726994375478416, 1],
#  'Wolkengebilde->lkluft': [0.6197564842794281, 2],
#  'Wolkengebilde->lpaccini': [2.868776152826258, 11],
#  'Wolkengebilde->lutz.hirsch': [0.5866544355923988, 2],
#  'Wolkengebilde->magio': [2.2414136577735304, 7],
#  'Wolkengebilde->majomi': [3.023841966297131, 8],
#  'Wolkengebilde->monika.esch': [1.2214685672654813, 8],
#  'Wolkengebilde->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'Wolkengebilde->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'Wolkengebilde->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'Wolkengebilde->onnoq': [1.3862195344522859, 8],
#  'Wolkengebilde->raspstephan': [0.34281070442788464, 2],
#  'Wolkengebilde->tmieslinger': [0, 0],
#  'Wolkengebilde->traute.crueger': [2.4945693971828637, 6],
#  'akio->Armin.haghshenas': [1.9511293133469705, 7],
#  'akio->CKauhs': [0.4669045175581206, 1],
#  'akio->CStephan': [0, 0],
#  'akio->DelaS': [1.30097273093684, 4],
#  'akio->JuleR': [0.6955440348625667, 3],
#  'akio->Julia.Windmiller': [0.2908982312783521, 4],
#  'akio->LWMPI': [1.151630441281089, 3],
#  'akio->MarcusKlingebiel': [0.9234793616191339, 2],
#  'akio->ReinhardB': [0.4565433160474349, 1],
#  'akio->Saybot': [2.6964647349820012, 6],
#  'akio->Serikov': [1.1607210750659174, 7],
#  'akio->ShCu': [3.4195130147988357, 9],
#  'akio->TobiasBecker': [3.994545114975436, 9],
#  'akio->Uthlande': [1.66111144022994, 5],
#  'akio->Wolkengebilde': [0.9810709551781207, 3],
#  'akio->akio': [179.0, 179],
#  'akio->anna.luebke': [2.1827476409825666, 6],
#  'akio->biancorosa': [0.5275514085331565, 3],
#  'akio->bjorn.stevens': [1.8421838625315838, 6],
#  'akio->bkirsch': [0.0, 1],
#  'akio->bko_cloud': [0.05958257556075171, 1],
#  'akio->bschul': [1.1364077199246445, 5],
#  'akio->cathyhohenegger': [4.4908129574966384, 11],
#  'akio->christopher.moseley': [0.8592203912724644, 2],
#  'akio->dleutwyler': [0.4117375988782024, 1],
#  'akio->double_p': [2.5485652626702047, 7],
#  'akio->elessar.telkontar': [2.4751591205459658, 7],
#  'akio->geetgeorge': [0, 0],
#  'akio->guidocioni': [1.6995576777440933, 4],
#  'akio->hartmut.borth': [1.078525881254114, 3],
#  'akio->heikekonow': [1.5952177732211206, 4],
#  'akio->jan.welss': [5.526963087065948, 14],
#  'akio->jkiliani': [0.8532674245530549, 3],
#  'akio->jpmellado': [3.6208708470457616, 8],
#  'akio->jvmpi': [1.9572612267339418, 3],
#  'akio->kfodor': [0.9275962881365993, 4],
#  'akio->lkluft': [0, 0],
#  'akio->lpaccini': [1.3066544050148599, 6],
#  'akio->lutz.hirsch': [1.5675851071541924, 3],
#  'akio->magio': [0.39327505362247156, 2],
#  'akio->majomi': [3.3350428381806543, 7],
#  'akio->monika.esch': [1.182216417828172, 5],
#  'akio->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'akio->not-logged-in-50dab35d7f338290c5f2': [0.7003070906188347, 2],
#  'akio->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'akio->onnoq': [0.16327139648483516, 1],
#  'akio->raspstephan': [0, 0],
#  'akio->tmieslinger': [0.6979258722973963, 1],
#  'akio->traute.crueger': [0, 0],
#  'anna.luebke->Armin.haghshenas': [2.709883746256872, 5],
#  'anna.luebke->CKauhs': [2.1991922382138576, 5],
#  'anna.luebke->CStephan': [3.050183225019209, 7],
#  'anna.luebke->DelaS': [1.1440989156316899, 4],
#  'anna.luebke->JuleR': [3.810022289860618, 10],
#  'anna.luebke->Julia.Windmiller': [3.3879447413214754, 8],
#  'anna.luebke->LWMPI': [3.336227328213191, 8],
#  'anna.luebke->MarcusKlingebiel': [0.5611986102608544, 1],
#  'anna.luebke->ReinhardB': [3.7777213623275094, 10],
#  'anna.luebke->Saybot': [4.1109694319863825, 12],
#  'anna.luebke->Serikov': [1.3527763193950102, 5],
#  'anna.luebke->ShCu': [3.838150703076618, 8],
#  'anna.luebke->TobiasBecker': [2.5873736204925426, 7],
#  'anna.luebke->Uthlande': [4.594247913088562, 9],
#  'anna.luebke->Wolkengebilde': [0.25650638177996404, 1],
#  'anna.luebke->akio': [2.1827476409825666, 6],
#  'anna.luebke->anna.luebke': [255.0, 255],
#  'anna.luebke->biancorosa': [2.230715730866553, 7],
#  'anna.luebke->bjorn.stevens': [4.2809077511045475, 10],
#  'anna.luebke->bkirsch': [1.3431352868560764, 3],
#  'anna.luebke->bko_cloud': [2.8312933111911667, 6],
#  'anna.luebke->bschul': [0.9847570219141515, 2],
#  'anna.luebke->cathyhohenegger': [3.3658794572558657, 10],
#  'anna.luebke->christopher.moseley': [1.3561441449325031, 3],
#  'anna.luebke->dleutwyler': [4.360410152037058, 7],
#  'anna.luebke->double_p': [2.650526187021481, 6],
#  'anna.luebke->elessar.telkontar': [0, 0],
#  'anna.luebke->geetgeorge': [1.222434393400304, 3],
#  'anna.luebke->guidocioni': [6.744090412491937, 14],
#  'anna.luebke->hartmut.borth': [1.4361356498448292, 4],
#  'anna.luebke->heikekonow': [2.0253687484751346, 8],
#  'anna.luebke->jan.welss': [5.36144606811204, 14],
#  'anna.luebke->jkiliani': [1.791616682427699, 6],
#  'anna.luebke->jpmellado': [5.033060238266188, 10],
#  'anna.luebke->jvmpi': [0, 0],
#  'anna.luebke->kfodor': [2.1246238251911542, 4],
#  'anna.luebke->lkluft': [1.088201603506871, 3],
#  'anna.luebke->lpaccini': [0, 0],
#  'anna.luebke->lutz.hirsch': [2.5924524336638264, 4],
#  'anna.luebke->magio': [2.2464415649482072, 7],
#  'anna.luebke->majomi': [3.162982763975517, 8],
#  'anna.luebke->monika.esch': [2.374223463091738, 7],
#  'anna.luebke->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'anna.luebke->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'anna.luebke->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'anna.luebke->onnoq': [3.497943651630293, 7],
#  'anna.luebke->raspstephan': [1.4688157878319323, 3],
#  'anna.luebke->tmieslinger': [0.5294359088990849, 1],
#  'anna.luebke->traute.crueger': [1.4380743683181718, 4],
#  'biancorosa->Armin.haghshenas': [5.574283664275553, 15],
#  'biancorosa->CKauhs': [3.990931483159426, 11],
#  'biancorosa->CStephan': [0.0, 1],
#  'biancorosa->DelaS': [1.9781560041519082, 8],
#  'biancorosa->JuleR': [5.1637528596712015, 9],
#  'biancorosa->Julia.Windmiller': [1.6282930007278953, 3],
#  'biancorosa->LWMPI': [2.7171715799012888, 7],
#  'biancorosa->MarcusKlingebiel': [2.478080468004159, 6],
#  'biancorosa->ReinhardB': [2.899508570153049, 14],
#  'biancorosa->Saybot': [3.90906741133681, 8],
#  'biancorosa->Serikov': [8.934604582297716, 24],
#  'biancorosa->ShCu': [3.3848153332595814, 9],
#  'biancorosa->TobiasBecker': [4.794431383200843, 12],
#  'biancorosa->Uthlande': [5.869581187513613, 15],
#  'biancorosa->Wolkengebilde': [2.534359826975601, 5],
#  'biancorosa->akio': [0.5275514085331565, 3],
#  'biancorosa->anna.luebke': [2.230715730866553, 7],
#  'biancorosa->biancorosa': [519.0, 519],
#  'biancorosa->bjorn.stevens': [3.564022385939262, 8],
#  'biancorosa->bkirsch': [2.1712088424704215, 4],
#  'biancorosa->bko_cloud': [1.8478585547124704, 5],
#  'biancorosa->bschul': [5.4393876949012405, 15],
#  'biancorosa->cathyhohenegger': [3.6261607113000225, 12],
#  'biancorosa->christopher.moseley': [5.318506425082925, 13],
#  'biancorosa->dleutwyler': [1.9034995108353172, 8],
#  'biancorosa->double_p': [3.7598564151195846, 7],
#  'biancorosa->elessar.telkontar': [7.213392632279153, 17],
#  'biancorosa->geetgeorge': [3.2979654730608727, 11],
#  'biancorosa->guidocioni': [7.92618113895044, 23],
#  'biancorosa->hartmut.borth': [3.90176971900188, 10],
#  'biancorosa->heikekonow': [0.6334877282928906, 3],
#  'biancorosa->jan.welss': [10.244825794752877, 25],
#  'biancorosa->jkiliani': [10.864947967127275, 26],
#  'biancorosa->jpmellado': [7.785642415285876, 15],
#  'biancorosa->jvmpi': [2.0266981723112747, 6],
#  'biancorosa->kfodor': [3.095425822525259, 5],
#  'biancorosa->lkluft': [2.166556727265894, 4],
#  'biancorosa->lpaccini': [5.113436553783598, 13],
#  'biancorosa->lutz.hirsch': [7.039204279867158, 17],
#  'biancorosa->magio': [9.537381821726143, 22],
#  'biancorosa->majomi': [7.106495223044347, 19],
#  'biancorosa->monika.esch': [4.938240185714548, 14],
#  'biancorosa->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'biancorosa->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'biancorosa->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'biancorosa->onnoq': [13.098586189276565, 30],
#  'biancorosa->raspstephan': [0.3050364334599811, 1],
#  'biancorosa->tmieslinger': [1.7343895967229064, 3],
#  'biancorosa->traute.crueger': [3.2031454837379787, 8],
#  'bjorn.stevens->Armin.haghshenas': [9.344670959562597, 16],
#  'bjorn.stevens->CKauhs': [2.3371708091465573, 6],
#  'bjorn.stevens->CStephan': [4.211780875456867, 9],
#  'bjorn.stevens->DelaS': [3.5814955700192743, 10],
#  'bjorn.stevens->JuleR': [8.866600383134958, 20],
#  'bjorn.stevens->Julia.Windmiller': [3.808070083132001, 10],
#  'bjorn.stevens->LWMPI': [6.1004755908692365, 13],
#  'bjorn.stevens->MarcusKlingebiel': [3.329471810023425, 7],
#  'bjorn.stevens->ReinhardB': [4.1840892084742345, 12],
#  'bjorn.stevens->Saybot': [2.7378764579268866, 7],
#  'bjorn.stevens->Serikov': [9.476183504186423, 22],
#  'bjorn.stevens->ShCu': [4.544701101553805, 11],
#  'bjorn.stevens->TobiasBecker': [4.694277963402254, 11],
#  'bjorn.stevens->Uthlande': [4.473760123979149, 12],
#  'bjorn.stevens->Wolkengebilde': [4.375880678801648, 11],
#  'bjorn.stevens->akio': [1.8421838625315838, 6],
#  'bjorn.stevens->anna.luebke': [4.2809077511045475, 10],
#  'bjorn.stevens->biancorosa': [3.564022385939262, 8],
#  'bjorn.stevens->bjorn.stevens': [481.0, 481],
#  'bjorn.stevens->bkirsch': [0.9010980703510933, 3],
#  'bjorn.stevens->bko_cloud': [3.966539822225558, 11],
#  'bjorn.stevens->bschul': [8.611196830410682, 19],
#  'bjorn.stevens->cathyhohenegger': [9.747781025497261, 24],
#  'bjorn.stevens->christopher.moseley': [5.729050181643883, 12],
#  'bjorn.stevens->dleutwyler': [4.15382451176667, 12],
#  'bjorn.stevens->double_p': [3.635916873988232, 9],
#  'bjorn.stevens->elessar.telkontar': [5.7653459001952445, 16],
#  'bjorn.stevens->geetgeorge': [3.230556597927001, 6],
#  'bjorn.stevens->guidocioni': [8.335358606031823, 17],
#  'bjorn.stevens->hartmut.borth': [4.0931105786406246, 8],
#  'bjorn.stevens->heikekonow': [2.6514478275231137, 9],
#  'bjorn.stevens->jan.welss': [14.642487587376381, 38],
#  'bjorn.stevens->jkiliani': [7.326414063330997, 17],
#  'bjorn.stevens->jpmellado': [8.559532508015215, 19],
#  'bjorn.stevens->jvmpi': [4.27524587881319, 8],
#  'bjorn.stevens->kfodor': [0.4858697061036841, 3],
#  'bjorn.stevens->lkluft': [1.8039778214869238, 3],
#  'bjorn.stevens->lpaccini': [5.791095032705227, 13],
#  'bjorn.stevens->lutz.hirsch': [5.135411464762694, 14],
#  'bjorn.stevens->magio': [4.848600660002927, 14],
#  'bjorn.stevens->majomi': [3.3889601205802578, 11],
#  'bjorn.stevens->monika.esch': [2.415417406192625, 9],
#  'bjorn.stevens->not-logged-in-0baa7228b5be68fb8e1a': [0.2459385444036065, 2],
#  'bjorn.stevens->not-logged-in-50dab35d7f338290c5f2': [1.1103058808458959, 2],
#  'bjorn.stevens->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'bjorn.stevens->onnoq': [6.5639989597984085, 13],
#  'bjorn.stevens->raspstephan': [0.3734197864827472, 1],
#  'bjorn.stevens->tmieslinger': [0, 0],
#  'bjorn.stevens->traute.crueger': [3.677234456088444, 11],
#  'bkirsch->Armin.haghshenas': [1.025933328040768, 3],
#  'bkirsch->CKauhs': [1.2449940039616503, 3],
#  'bkirsch->CStephan': [0.5419341817364487, 1],
#  'bkirsch->DelaS': [1.3180869377804183, 3],
#  'bkirsch->JuleR': [0.46668945853124366, 1],
#  'bkirsch->Julia.Windmiller': [1.4447076115889013, 4],
#  'bkirsch->LWMPI': [0.576465541640133, 1],
#  'bkirsch->MarcusKlingebiel': [1.0031819590955497, 4],
#  'bkirsch->ReinhardB': [0.07299013257848358, 2],
#  'bkirsch->Saybot': [1.1999231351683446, 2],
#  'bkirsch->Serikov': [3.847152376481476, 8],
#  'bkirsch->ShCu': [2.655632803910786, 8],
#  'bkirsch->TobiasBecker': [3.287579645261642, 9],
#  'bkirsch->Uthlande': [1.7843322752706021, 5],
#  'bkirsch->Wolkengebilde': [1.894944003693713, 4],
#  'bkirsch->akio': [0.0, 1],
#  'bkirsch->anna.luebke': [1.3431352868560764, 3],
#  'bkirsch->biancorosa': [2.1712088424704215, 4],
#  'bkirsch->bjorn.stevens': [0.9010980703510933, 3],
#  'bkirsch->bkirsch': [130.0, 130],
#  'bkirsch->bko_cloud': [0.0, 1],
#  'bkirsch->bschul': [3.5264715941081706, 9],
#  'bkirsch->cathyhohenegger': [3.8595044465097925, 8],
#  'bkirsch->christopher.moseley': [0.3552191616190028, 1],
#  'bkirsch->dleutwyler': [0, 0],
#  'bkirsch->double_p': [0.41467129034604844, 1],
#  'bkirsch->elessar.telkontar': [2.273944364918356, 6],
#  'bkirsch->geetgeorge': [0, 0],
#  'bkirsch->guidocioni': [1.2989571881714337, 4],
#  'bkirsch->hartmut.borth': [0.966311238382337, 2],
#  'bkirsch->heikekonow': [0.0, 1],
#  'bkirsch->jan.welss': [3.1814790036303213, 8],
#  'bkirsch->jkiliani': [0.6006922144422039, 2],
#  'bkirsch->jpmellado': [1.8745224384480328, 5],
#  'bkirsch->jvmpi': [0.8374944668841511, 2],
#  'bkirsch->kfodor': [1.4291380802440476, 2],
#  'bkirsch->lkluft': [0, 0],
#  'bkirsch->lpaccini': [3.693890202674229, 11],
#  'bkirsch->lutz.hirsch': [3.48413960997702, 7],
#  'bkirsch->magio': [2.4637281195852445, 7],
#  'bkirsch->majomi': [2.269110987429805, 5],
#  'bkirsch->monika.esch': [2.135760020225268, 6],
#  'bkirsch->not-logged-in-0baa7228b5be68fb8e1a': [0, 0],
#  'bkirsch->not-logged-in-50dab35d7f338290c5f2': [0, 0],
#  'bkirsch->not-logged-in-c9c96a955486304fe369': [0, 0],
#  'bkirsch->onnoq': [0.12485281085739952, 1],
#  'bkirsch->raspstephan': [0, 0],
#  'bkirsch->tmieslinger': [0, 0],
#  'bkirsch->traute.crueger': [0, 0],
#  'bko_cloud->Armin.haghshenas': [4.029801443215012, 11],
#  'bko_cloud->CKauhs': [2.1414605628416457, 4],
#  'bko_cloud->CStephan': [2.902376249468031, 6],
#  'bko_cloud->DelaS': [1.7006408602592682, 5],
#  'bko_cloud->JuleR': [4.3190266878376695, 9],
#  'bko_cloud->Julia.Windmiller': [2.6091874305735603, 9],
#  'bko_cloud->LWMPI': [5.4870480318114865, 13],
#  'bko_cloud->MarcusKlingebiel': [3.4365110684228757, 7],
#  'bko_cloud->ReinhardB': [0.9037375581600801, 2],
#  'bko_cloud->Saybot': [3.4938537956149123, 6],
#  'bko_cloud->Serikov': [8.621485249763982, 17],
#  'bko_cloud->ShCu': [3.5324760565366455, 8],
#  'bko_cloud->TobiasBecker': [1.819886196993425, 7],
#  'bko_cloud->Uthlande': [1.5444880542977226, 4],
#  'bko_cloud->Wolkengebilde': [0.8087736151136727, 2],
#  'bko_cloud->akio': [0.05958257556075171, 1],
#  'bko_cloud->anna.luebke': [2.8312933111911667, 6],
#  'bko_cloud->biancorosa': [1.8478585547124704, 5],
#  'bko_cloud->bjorn.stevens': [3.966539822225558, 11],
#  'bko_cloud->bkirsch': [0.0, 1],
#  ...}

# %%
# Create IoU matrix
user_index_dict = {}
for ind, name in enumerate(np.unique(annos_df.user)):
    user_index_dict[name] = ind

# %%
IoU_matrix = np.zeros((len(np.unique(annos_df.user)),len(np.unique(annos_df.user))))
for pair, values in IoU_pairs.items():
    IoU_sum, N = values
    if N > 0:
        IoU_mean = IoU_sum/N
    else:
        IoU_mean = np.nan
    user1_name, user2_name = pair.split('->')
    user1_id = user_index_dict[user1_name]
    user2_id = user_index_dict[user2_name]
    IoU_matrix[user1_id, user2_id] = IoU_mean

# %%
import seaborn as sns
plt.figure(figsize=(25,20))
ax = sns.heatmap(IoU_matrix, annot=False, cmap='Blues',cbar=False)
ax.set_xticklabels(user_index_dict.keys(),rotation=90);
ax.set_yticklabels(user_index_dict.keys(),rotation=0);

# %% [markdown]
# I forgot to split the results by classes during the calculation, so this is now the mean for all classes.

# %% [markdown]
# Sorting the matrix by the standard deviation each user has among its IoU should give a rough estimate, how its total ranking among the users is. Although actually the mean should by high as well! However, the matrix calculated based on the mean (just change the next line) does not show a clear behaviour.

# %%
sort_ind = np.argsort(np.nanstd(IoU_matrix,axis=1))

# %%
users = np.array(list(user_index_dict.keys()))

# %%
plt.figure(figsize=(22,20))
plt.title('User agreement based on IoU\nsorted by standard deviation',fontsize=20)
ax = sns.heatmap(IoU_matrix[sort_ind][:,sort_ind], annot=False, cmap='Blues',cbar=False)
ax.set_xticklabels(users[sort_ind],rotation=90);
ax.set_yticklabels(users[sort_ind],rotation=0);
plt.tight_layout()

# %% [markdown]
# ## Retrieve cluster of user

# %% [markdown]
# Now a further difficulty is to decide on a threshold, which users we would trust and which we will not. I first thought of creating an N dimensional space where N is equal to the number of user pairs (without permutations and identities) and each IoU would be the support of a point in space. Then one could find the centroid and define some sort of n-sphere around this. Points/Users within this sphere would be trusted, the others not.
# So basically a k-mean analysis with k=1.

# %% [markdown]
# ## Validating the selection

# %% [markdown]
# After we found a group of users we can trust, I would validate our approach by comparing e.g. the mean IoU of the practical dataset with all users to the mean IoU from the 'good' users only. If this leads to an improvement, we have done a good job!

# %% [markdown]
# ## Still to do
# - think about a good IoU or comparable measure
# - decide on 'good' and 'bad' users
# - include the type of class in the decision making (i.e. one user agrees well with others for fish, but has low IoUs when he classifies sugar)

# %% [markdown]
# Hauke out!
