# %%
import pandas as pd

# %%
fn = '/home/s/S.Rasp/Downloads/new-workflow-classifications.csv'

# %%
df = pd.read_csv(fn)

# %%
df
# Out:
#     classification_id      user_name  user_id               user_ip  \
# 0           126102667    raspstephan  1814911  3ec81a02d17a1f7b9b1f
# 1           126385352  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 2           126385422  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 3           126385503  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 4           126385605  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 5           126385723  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 6           126385887  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 7           126385955  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 8           126386039  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 9           126386148  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 10          126386227  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 11          126386304  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# 12          126386367  bjorn.stevens  1825300  59a0e60630a3e4d8397d
# ...

# %%
len(df)
# Out:
# 61

# %%
df['annotations'][20]
# Out:
# '[{"task":"T0","task_label":"Explain what to draw.","value":[{"x":831.010009765625,"y":186.54261779785156,"tool":1,"frame":0,"width":1012.4344482421875,"height":580.9394989013672,"details":[],"tool_label":"Gravel"}]}]'
