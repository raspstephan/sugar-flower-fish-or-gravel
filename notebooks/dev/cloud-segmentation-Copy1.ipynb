# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *

# %%
get_ipython().config.get('IPKernelApp', {})['parent_appname'] = ""

# %%
SSDDIR = '/local/S.Rasp/cloud-classification/'

# %%
df = pd.read_csv(SSDDIR + 'fastai.csv', index_col=0); df.head()
# Out:
#                                                   fn  \
# 0  Region1_MAM_Aqua/Aqua_CorrectedReflectance2007...
# 1  Region3_DJF_Aqua/Aqua_CorrectedReflectance2015...
# 2  Region3_SON_Terra/Terra_CorrectedReflectance20...
# 3  Region1_DJF_Aqua/Aqua_CorrectedReflectance2011...
# 4  Region1_DJF_Aqua/Aqua_CorrectedReflectance2011...
#
#                                                 mask
# 0  masks/Region1_MAM_Aqua/Aqua_CorrectedReflectan...
# 1  masks/Region3_DJF_Aqua/Aqua_CorrectedReflectan...
# 2  masks/Region3_SON_Terra/Terra_CorrectedReflect...
# 3  masks/Region1_DJF_Aqua/Aqua_CorrectedReflectan...
# 4  masks/Region1_DJF_Aqua/Aqua_CorrectedReflectan...

# %%
df = df.iloc[:5000]

# %%
len(df)
# Out:
# 5000

# %%
df.fn.apply(lambda fn: 'Region2' in fn).sum()
# Out:
# 1026

# %%
df['mask'] = df['mask'].apply(lambda fn: SSDDIR + fn); df.head()
# Out:
#                                                   fn  \
# 0  Region1_MAM_Aqua/Aqua_CorrectedReflectance2007...
# 1  Region3_DJF_Aqua/Aqua_CorrectedReflectance2015...
# 2  Region3_SON_Terra/Terra_CorrectedReflectance20...
# 3  Region1_DJF_Aqua/Aqua_CorrectedReflectance2011...
# 4  Region1_DJF_Aqua/Aqua_CorrectedReflectance2011...
#
#                                                 mask
# 0  /local/S.Rasp/cloud-classification/masks/Regio...
# 1  /local/S.Rasp/cloud-classification/masks/Regio...
# 2  /local/S.Rasp/cloud-classification/masks/Regio...
# 3  /local/S.Rasp/cloud-classification/masks/Regio...
# 4  /local/S.Rasp/cloud-classification/masks/Regio...

# %%
src = SegmentationItemList.from_df(df, path = SSDDIR); src
# Out:
# SegmentationItemList (5000 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification

# %%
src = src.split_by_valid_func(lambda fn: 'Region2' in fn); src
# Out:
# ItemLists;
#
# Train: SegmentationItemList (3974 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification;
#
# Valid: SegmentationItemList (1026 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification;
#
# Test: None

# %%
classes = ['Background', 'Sugar', 'Flower', 'Fish', 'Gravel']

# %%
src = src.label_from_df('mask', classes=['Background', 'Sugar', 'Flower', 'Fish', 'Gravel']); src
# Out:
# LabelLists;
#
# Train: LabelList
# y: SegmentationLabelList (3974 items)
# [ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification
# x: SegmentationItemList (3974 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification;
#
# Valid: LabelList
# y: SegmentationLabelList (1026 items)
# [ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification
# x: SegmentationItemList (1026 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification;
#
# Test: None

# %%
size = np.array([1400, 2100]) // 5; size
# Out:
# array([280, 420])

# %%
np.array([1400, 2100]) / 5
# Out:
# array([280., 420.])

# %%
data = src.transform(get_transforms(), size=size.astype(int), tfm_y=True); data
# Out:
# LabelLists;
#
# Train: LabelList
# y: SegmentationLabelList (3974 items)
# [ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification
# x: SegmentationItemList (3974 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification;
#
# Valid: LabelList
# y: SegmentationLabelList (1026 items)
# [ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100), ImageSegment (1, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification
# x: SegmentationItemList (1026 items)
# [Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100), Image (3, 1400, 2100)]...
# Path: /local/S.Rasp/cloud-classification;
#
# Test: None

# %%
data = data.databunch(bs=4*3)

# %%
data = data.normalize(imagenet_stats)

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %%
x, y = next(iter(data.valid_dl))

# %%
x.size()
# Out:
# torch.Size([12, 3, 280, 420])

# %%
y.size()
# Out:
# torch.Size([12, 1, 280, 420])

# %% [markdown]
# ## model

# %%
codes = ['Background', 'Sugar', 'Flower', 'Fish', 'Gravel']

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Background']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet18, metrics=metrics, wd=wd, pretrained=True)

# %%
learn.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %%
# learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-4

# %%
doc(learn.fit_one_cycle)

# %%
learn.fit_one_cycle(1, max_lr=lr, wd=wd)
# Out:
# Total time: 05:20 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.802279</th>
#     <th>0.796888</th>
#     <th>0.009217</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(1, max_lr=lr, wd=wd)
# Out:
# Total time: 05:17 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.758960</th>
#     <th>0.757842</th>
#     <th>0.045531</th>
#   </tr>
# </table>

# %%
learn.save('pt_f1')

# %%
learn.fit_one_cycle(1, max_lr=lr, wd=wd)
# Out:
# Total time: 05:13 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.745337</th>
#     <th>0.744138</th>
#     <th>0.048323</th>
#   </tr>
# </table>

# %%
learn.save('pt_f1')

# %%
learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lrs = slice(1e-5/100, 1e-5)

# %%
learn.fit_one_cycle(1, max_lr=lrs, wd=wd)
# Out:
# Total time: 05:23 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.739648</th>
#     <th>0.735166</th>
#     <th>0.109524</th>
#   </tr>
# </table>

# %%
learn.save('pt_f1')

# %%
lr_find(learn, start_lr=1e-9, end_lr=1e-2)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lrs = slice(1e-7/100, 1e-7)

# %%
learn.fit_one_cycle(1, max_lr=lrs, wd=wd)
# Out:
# Total time: 05:25 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.750223</th>
#     <th>0.733072</th>
#     <th>0.113524</th>
#   </tr>
# </table>

# %%
learn.save('pt_f2')

# %%
learn.fit_one_cycle(3, max_lr=lrs, wd=wd)
# Out:
# Total time: 16:14 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.740453</th>
#     <th>0.737427</th>
#     <th>0.126970</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.708979</th>
#     <th>0.735767</th>
#     <th>0.114559</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.751258</th>
#     <th>0.732473</th>
#     <th>0.115487</th>
#   </tr>
# </table>

# %%
img, true = data.valid_ds[2]

# %%
img.shape, true.shape
# Out:
# (torch.Size([3, 280, 420]), torch.Size([1, 280, 420]))

# %%
img
# Out:
# Image (3, 280, 420)

# %%
true.
# Out:
#   File "<ipython-input-193-23ff3e51beee>", line 1
#     true.
#          ^
# SyntaxError: invalid syntax

# %%
true
# Out:
# ImageSegment (1, 280, 420)

# %%
p = learn.predict(img)

# %%
p[0]
# Out:
# ImageSegment (1, 280, 420)

# %%
p[1].shape
# Out:
# torch.Size([1, 280, 420])

# %%
np.bincount(p[1].numpy().flatten())
# Out:
# array([117483,      0,      0,      5,    112])

# %%
p[2].shape
# Out:
# torch.Size([5, 280, 420])

# %%
npp = p[2].numpy()

# %%
npp.shape
# Out:
# (5, 280, 420)

# %%
np.argmax(p[2], 0).shape
# Out:
# torch.Size([280, 420])

# %%
import scipy

# %%
scipy.__version__
# Out:
# '1.2.0'

# %%
from scipy.ndimage import gaussian_filter

# %%
def get_max_class(p, thresh=0.3, smooth=False):
    x = p[2].numpy().copy()
    if smooth:
        for i in range(x.shape[0]):
            x[i] = gaussian_filter(x[i], 10)
    x[0][np.max(x[1:], 0) > thresh] = 0
    return np.argmax(x, 0)

# %%
a = get_max_class(p, 0.2, True)

# %%
classes

# %%
plt.imshow(a)
plt.colorbar()

# %%
# %debug
# Out:
# > <ipython-input-204-fb55651843ed>(5)get_max_class()
#       3     if smooth:
#       4         for i in range(x.shape[0]):
# ----> 5             x[i] = gaussian_filter(x, 10)
#       6     x[0][np.max(x[1:], 0) > thresh] = 0
#       7     return np.argmax(x, 0)

# %%
plt.matshow(p[2].numpy()[0])
plt.colorbar()

# %%
classes
# Out:
# ['Background', 'Sugar', 'Flower', 'Fish', 'Gravel']

# %%
img
# Out:
# Image (3, 280, 420)

# %%
plt.matshow(p[2].numpy()[1] > 0.1)

# %%
p = learn.predict(x); p.size()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c36edb04ca3c> in <module>
# ----> 1 p = learn.predict(x); p.size()
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in predict(self, item, **kwargs)
#     280     def predict(self, item:ItemBase, **kwargs):
#     281         "Return predicted class, label and probabilities for `item`."
# --> 282         batch = self.data.one_item(item)
#     283         res = self.pred_batch(batch=batch)
#     284         pred,x = res[0],batch[0]
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_data.py in one_item(self, item, detach, denorm, cpu)
#     153         ds = self.single_ds
#     154         with ds.set_item(item):
# --> 155             return self.one_batch(ds_type=DatasetType.Single, detach=detach, denorm=denorm, cpu=cpu)
#     156
#     157     def show_batch(self, rows:int=5, ds_type:DatasetType=DatasetType.Train, **kwargs)->None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_data.py in one_batch(self, ds_type, detach, denorm, cpu)
#     140         w = self.num_workers
#     141         self.num_workers = 0
# --> 142         try:     x,y = next(iter(dl))
#     143         finally: self.num_workers = w
#     144         if detach: x,y = to_detach(x,cpu=cpu),to_detach(y,cpu=cpu)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_data.py in __iter__(self)
#      69     def __iter__(self):
#      70         "Process and returns items from `DataLoader`."
# ---> 71         for b in self.dl: yield self.proc_batch(b)
#      72
#      73     @classmethod
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/data_block.py in __getitem__(self, idxs)
#     565             else:                 x,y = self.item   ,0
#     566             if self.tfms or self.tfmargs:
# --> 567                 x = x.apply_tfms(self.tfms, **self.tfmargs)
#     568             if hasattr(self, 'tfms_y') and self.tfm_y and self.item is None:
#     569                 y = y.apply_tfms(self.tfms_y, **{**self.tfmargs_y, 'do_resolve':False})
#
# AttributeError: 'Tensor' object has no attribute 'apply_tfms'

# %%
learn.validate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-631604a2e07b> in <module>
# ----> 1 learn.validate()
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in validate(self, dl, callbacks, metrics)
#     298         cb_handler = CallbackHandler(self.callbacks + ifnone(callbacks, []), metrics)
#     299         cb_handler.on_epoch_begin()
# --> 300         val_metrics = validate(self.model, dl, self.loss_func, cb_handler)
#     301         cb_handler.on_epoch_end(val_metrics)
#     302         return cb_handler.state_dict['last_metrics']
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in validate(model, dl, loss_func, cb_handler, pbar, average, n_batch)
#      52         for xb,yb in progress_bar(dl, parent=pbar, leave=(pbar is not None)):
#      53             if cb_handler: xb, yb = cb_handler.on_batch_begin(xb, yb, train=False)
# ---> 54             val_losses.append(loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler))
#      55             if not is_listy(yb): yb = [yb]
#      56             nums.append(yb[0].shape[0])
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      32         opt.zero_grad()
#      33
# ---> 34     return loss.detach().cpu()
#      35
#      36 def get_preds(model:nn.Module, dl:DataLoader, pbar:Optional[PBar]=None, cb_handler:Optional[CallbackHandler]=None,
#
# KeyboardInterrupt:

# %%
learn.fit_one_cycle(1, slice(lr), pct_start=0.9)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='6065', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-5ef34c3464f6> in <module>
# ----> 1 learn.fit_one_cycle(2, slice(lr), pct_start=0.9)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     176         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     177         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 178             callbacks=self.callbacks+callbacks)
#     179
#     180     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      83
#      84         try:
# ---> 85             return func(*args, **kwargs)
#      86         except Exception as e:
#      87             if "CUDA out of memory" in str(e) or tb_clear_frames=="1":
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      88             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      89                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 90                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      91                 if cb_handler.on_batch_end(loss): break
#      92
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      28         loss.backward()
#      29         cb_handler.on_backward_end()
# ---> 30         opt.step()
#      31         cb_handler.on_step_end()
#      32         opt.zero_grad()
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/callback.py in step(self)
#      45                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#      46             self.set_val('weight_decay', listify(0, self._wd))
# ---> 47         self.opt.step()
#      48
#      49     def zero_grad(self)->None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     105                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     106
# --> 107                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     108
#     109         return loss
#
# KeyboardInterrupt:

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/100,lr)

# %%
learn.fit_one_cycle(10, lrs, pct_start=0.8)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='61', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-7006a896fec6> in <module>
# ----> 1 learn.fit_one_cycle(10, lrs, pct_start=0.8)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     176         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     177         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 178             callbacks=self.callbacks+callbacks)
#     179
#     180     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      87             if "CUDA out of memory" in str(e) or tb_clear_frames=="1":
#      88                 type, val, tb = get_ref_free_exc_info() # must!
# ---> 89                 raise type(val).with_traceback(tb) from None
#      90             else: raise # re-raises the exact last exception
#      91     return wrapper
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      83
#      84         try:
# ---> 85             return func(*args, **kwargs)
#      86         except Exception as e:
#      87             if "CUDA out of memory" in str(e) or tb_clear_frames=="1":
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(***failed resolving arguments***)
#      98     except Exception as e:
#      99         exception = e
# --> 100         raise e
#     101     finally: cb_handler.on_train_end(exception)
#     102
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(***failed resolving arguments***)
#      88             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      89                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 90                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      91                 if cb_handler.on_batch_end(loss): break
#      92
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(***failed resolving arguments***)
#      18     if not is_listy(xb): xb = [xb]
#      19     if not is_listy(yb): yb = [yb]
# ---> 20     out = model(*xb)
#      21     out = cb_handler.on_loss_begin(out)
#      22
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/layers.py in forward(***failed resolving arguments***)
#     119         for l in self.layers:
#     120             res.orig = x
# --> 121             nres = l(res)
#     122             # We have to remove res.orig to avoid hanging refs and therefore memory leaks
#     123             res.orig = None
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/vision/models/unet.py in forward(***failed resolving arguments***)
#      28     def forward(self, up_in:Tensor) -> Tensor:
#      29         s = self.hook.stored
# ---> 30         up_out = self.shuf(up_in)
#      31         ssh = s.shape[-2:]
#      32         if ssh != up_out.shape[-2:]:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/layers.py in forward(***failed resolving arguments***)
#     211     def forward(self,x):
#     212         x = self.shuf(self.relu(self.conv(x)))
# --> 213         return self.blur(self.pad(x)) if self.blur else x
#     214
#     215 class FlattenedLoss():
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/padding.py in forward(***failed resolving arguments***)
#     274     @weak_script_method
#     275     def forward(self, input):
# --> 276         return F.pad(input, self.padding, 'replicate')
#     277
#     278     def extra_repr(self):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/functional.py in pad(***failed resolving arguments***)
#    2685                 ret = torch._C._nn.reflection_pad2d(input, pad)
#    2686             elif mode == 'replicate':
# -> 2687                 ret = torch._C._nn.replication_pad2d(input, pad)
#    2688             else:
#    2689                 ret = input  # TODO: remove this when jit raise supports control flow
#
# RuntimeError: CUDA out of memory. Tried to allocate 26.00 MiB (GPU 0; 7.93 GiB total capacity; 5.04 GiB already allocated; 39.88 MiB free; 16.65 MiB cached)

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-dd390b1c8108> in <module>
# ----> 1 lr_find(learn)
#       2 learn.recorder.plot()
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, **kwargs)
#      30     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      31     a = int(np.ceil(num_it/len(learn.data.train_dl)))
# ---> 32     learn.fit(a, start_lr, callbacks=[cb], **kwargs)
#      33
#      34 def to_fp16(learn:Learner, loss_scale:float=512., flat_master:bool=False)->Learner:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     176         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     177         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 178             callbacks=self.callbacks+callbacks)
#     179
#     180     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      87             if "CUDA out of memory" in str(e) or tb_clear_frames=="1":
#      88                 type, val, tb = get_ref_free_exc_info() # must!
# ---> 89                 raise type(val).with_traceback(tb) from None
#      90             else: raise # re-raises the exact last exception
#      91     return wrapper
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      83
#      84         try:
# ---> 85             return func(*args, **kwargs)
#      86         except Exception as e:
#      87             if "CUDA out of memory" in str(e) or tb_clear_frames=="1":
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(***failed resolving arguments***)
#      99         exception = e
#     100         raise e
# --> 101     finally: cb_handler.on_train_end(exception)
#     102
#     103 loss_func_name2activ = {'cross_entropy_loss': F.softmax, 'nll_loss': torch.exp, 'poisson_nll_loss': torch.exp,
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/callback.py in on_train_end(***failed resolving arguments***)
#     274     def on_train_end(self, exception:Union[bool,Exception])->None:
#     275         "Handle end of training, `exception` is an `Exception` or False if no exceptions during training."
# --> 276         self('train_end', exception=exception)
#     277
#     278 class AverageMetric(Callback):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/callback.py in __call__(***failed resolving arguments***)
#     198         "Call through to all of the `CallbakHandler` functions."
#     199         if call_mets: [getattr(met, f'on_{cb_name}')(**self.state_dict, **kwargs) for met in self.metrics]
# --> 200         return [getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs) for cb in self.callbacks]
#     201
#     202     def set_dl(self, dl:DataLoader):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/callback.py in <listcomp>(***failed resolving arguments***)
#     198         "Call through to all of the `CallbakHandler` functions."
#     199         if call_mets: [getattr(met, f'on_{cb_name}')(**self.state_dict, **kwargs) for met in self.metrics]
# --> 200         return [getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs) for cb in self.callbacks]
#     201
#     202     def set_dl(self, dl:DataLoader):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/callbacks/lr_finder.py in on_train_end(***failed resolving arguments***)
#      43         # restore the valid_dl we turned off on `__init__`
#      44         self.data.valid_dl = self.valid_dl
# ---> 45         self.learn.load('tmp')
#      46         if hasattr(self.learn.model, 'reset'): self.learn.model.reset()
#      47         print('LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.')
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in load(***failed resolving arguments***)
#     236         "Load model and optimizer state (if `with_opt`) `name` from `self.model_dir` using `device`."
#     237         if device is None: device = self.data.device
# --> 238         state = torch.load(self.path/self.model_dir/f'{name}.pth', map_location=device)
#     239         if set(state.keys()) == {'model', 'opt'}:
#     240             get_model(self.model).load_state_dict(state['model'], strict=strict)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in load(***failed resolving arguments***)
#     365         f = open(f, 'rb')
#     366     try:
# --> 367         return _load(f, map_location, pickle_module)
#     368     finally:
#     369         if new_fd:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in _load(***failed resolving arguments***)
#     536     unpickler = pickle_module.Unpickler(f)
#     537     unpickler.persistent_load = persistent_load
# --> 538     result = unpickler.load()
#     539
#     540     deserialized_storage_keys = pickle_module.load(f)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in persistent_load(***failed resolving arguments***)
#     502             if root_key not in deserialized_objects:
#     503                 deserialized_objects[root_key] = restore_location(
# --> 504                     data_type(size), location)
#     505             storage = deserialized_objects[root_key]
#     506             if view_metadata is not None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in restore_location(***failed resolving arguments***)
#     385     elif isinstance(map_location, torch.device):
#     386         def restore_location(storage, location):
# --> 387             return default_restore_location(storage, str(map_location))
#     388     else:
#     389         def restore_location(storage, location):
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in default_restore_location(***failed resolving arguments***)
#     111 def default_restore_location(storage, location):
#     112     for _, _, fn in _package_registry:
# --> 113         result = fn(storage, location)
#     114         if result is not None:
#     115             return result
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in _cuda_deserialize(***failed resolving arguments***)
#      93     if location.startswith('cuda'):
#      94         device = validate_cuda_device(location)
# ---> 95         return obj.cuda(device)
#      96
#      97
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/_utils.py in _cuda(***failed resolving arguments***)
#      74         else:
#      75             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 76             return new_type(self.size()).copy_(self, non_blocking)
#      77
#      78
#
# RuntimeError: CUDA out of memory. Tried to allocate 9.00 MiB (GPU 0; 7.93 GiB total capacity; 4.93 GiB already allocated; 25.50 MiB free; 4.90 MiB cached)

# %%
# %debug
# Out:
# > /home/s/S.Rasp/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/layers.py(138)forward()
#     136         self.dense=dense
#     137
# --> 138     def forward(self, x): return torch.cat([x,x.orig], dim=1) if self.dense else (x+x.orig)
#     139
#     140 def res_block(nf, dense:bool=False, norm_type:Optional[NormType]=NormType.Batch, bottle:bool=False, **kwargs):
#
# ipdb> x.size()
# torch.Size([4, 96, 350, 526])
# ipdb> u
# > /home/s/S.Rasp/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py(489)__call__()
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ipdb> input
# (tensor([[[[5.2514e-01, 5.2514e-01, 6.2654e-01,  ..., 1.5393e-02,
#            3.3550e-01, 6.5560e-01],
#           [5.2514e-01, 5.2514e-01, 6.2654e-01,  ..., 1.5393e-02,
#            3.3550e-01, 6.5560e-01],
#           [6.6489e-01, 6.6489e-01, 9.5745e-01,  ..., 3.0494e-01,
#            4.7462e-01, 6.4429e-01],
#           ...,
#           [8.9376e-01, 8.9376e-01, 1.2368e+00,  ..., 1.1313e+00,
#            1.1459e+00, 1.1605e+00],
#           [1.5342e+00, 1.5342e+00, 1.5702e+00,  ..., 9.2444e-01,
#            9.7197e-01, 1.0195e+00],
#           [2.1746e+00, 2.1746e+00, 1.9036e+00,  ..., 7.1754e-01,
#            7.9802e-01, 8.7850e-01]],
#
#          [[0.0000e+00, 0.0000e+00,
-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 2.6971e-01,  ..., 1.2851e+00,
#            9.0567e-01, 5.2624e-01],
#           [1.3768e-01, 1.3768e-01, 5.1134e-01,  ..., 1.1967e+00,
#            9.3962e-01, 6.8253e-01],
#           [2.7535e-01, 2.7535e-01, 7.5297e-01,  ..., 1.1083e+00,
#            9.7356e-01, 8.3883e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.4653e-01, 4.9307e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.4653e-01, 4.9307e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.2327e-01, 2.4653e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]], device='cuda:0',
#        grad_fn=<AvgPool2DBackward>),)
# ipdb> input.size()
# *** AttributeError: 'tuple' object has no attribute 'size'
# ipdb> input[0].size()
# torch.Size([4, 96, 350, 526])
# ipdb> l
#     484         for hook in self._forward_pre_hooks.values():
#     485             hook(self, input)
#     486         if torch._C._get_tracing_state():
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#     492             if hook_result is not None:
#     493                 raise RuntimeError(
#     494                     "forward hooks should never return any values, but '{}'"
#
# ipdb> u
# > /home/s/S.Rasp/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/layers.py(121)forward()
#     119         for l in self.layers:
#     120             res.orig = x
# --> 121             nres = l(res)
#     122             # We have to remove res.orig to avoid hanging refs and therefore memory leaks
#     123             res.orig = None
#
# ipdb> res
# tensor([[[[5.2514e-01, 5.2514e-01, 6.2654e-01,  ..., 1.5393e-02,
#            3.3550e-01, 6.5560e-01],
#           [5.2514e-01, 5.2514e-01, 6.2654e-01,  ..., 1.5393e-02,
#            3.3550e-01, 6.5560e-01],
#           [6.6489e-01, 6.6489e-01, 9.5745e-01,  ..., 3.0494e-01,
#            4.7462e-01, 6.4429e-01],
#           ...,
#           [8.9376e-01, 8.9376e-01, 1.2368e+00,  ..., 1.1313e+00,
#            1.1459e+00, 1.1605e+00],
#           [1.5342e+00, 1.5342e+00, 1.5702e+00,  ..., 9.2444e-01,
#            9.7197e-01, 1.0195e+00],
#           [2.1746e+00, 2.1746e+00, 1.9036e+00,  ..., 7.1754e-01,
#            7.9802e-01, 8.7850e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 5.7154e-02,  ..., 0.0000e+00,
#            2.1445e-01, 4.2891e-01],
#           [0.0000e+00, 0.0000e+00, 5.7154e-02,  ..., 0.0000e+00,
#            2.1445e-01, 4.2891e-01],
#           [3.0055e-01, 3.0055e-01, 3.5647e-01,  ..., 4.9727e-02,
#            1.9425e-01, 3.3877e-01],
#           ...,
#           [7.9774e-01, 7.9774e-01, 5.7415e-01,  ..., 2.8970e-02,
#            3.8383e-01, 7.3869e-01],
#           [3.9887e-01, 3.9887e-01, 5.4816e-01,  ..., 2.2673e-01,
#            5.3478e-01, 8.4283e-01],
#           [0.0000e+00, 0.0000e+00, 5.2216e-01,  ..., 4.2448e-01,
#            6.8573e-01, 9.4698e-01]],
#
#          [[1.1106e+00, 1.1106e+00, 1.0044e+00,  ..., 0.0000e+00,
#            7.1664e-01, 1.4333e+00],
#           [1.1106e+00, 1.1106e+00, 1.0044e+00,  ..., 0.0000e+00,
#            7.1664e-01, 1.4333e+00],
#           [1.4113e+00, 1.4113e+00, 1.4727e+00,  ..., 5.8167e-01,
#            1.1275e+00, 1.6733e+00],
#           ...,
#           [1.9023e+00, 1.9023e+00, 2.4139e+00,  ..., 1.8813e+00,
#            1.8480e+00, 1.8146e+00],
#           [1.4822e+00, 1.4822e+00, 2.1254e+00,  ..., 1.8304e+00,
#            1.6623e+00, 1.4942e+00],
#           [1.0620e+00, 1.0620e+00, 1.8370e+00,  ..., 1.7795e+00,
#            1.4766e+00, 1.1737e+00]],
#
#          ...,
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8831e-01,
#            2.9440e-01, 1.0048e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8831e-01,
#            2.9440e-01, 1.0048e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.1855e-01,
#            2.3440e-01, 5.0241e-02],
#           ...,
#           [2.9654e-01, 2.9654e-01, 1.4827e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.4827e-01, 1.4827e-01, 7.4134e-02,  ..., 3.9152e-02,
#            1.9576e-02, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 7.8303e-02,
#            3.9152e-02, 0.0000e+00]],
#
#          [[8.6643e-01, 8.6643e-01, 1.1902e+00,  ..., 6.7766e-01,
#            6.4759e-01, 6.1752e-01],
#           [8.6643e-01, 8.6643e-01, 1.1902e+00,  ..., 6.7766e-01,
#            6.4759e-01, 6.1752e-01],
#           [4.3322e-01, 4.3322e-01, 6.0419e-01,  ..., 8.6449e-01,
#            5.8662e-01, 3.0876e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 2.6249e-01,  ..., 8.6498e-01,
#            8.9789e-01, 9.3080e-01],
#           [1.5616e-01, 1.5616e-01, 5.1457e-01,  ..., 9.1352e-01,
#            8.6145e-01, 8.0937e-01],
#           [3.1231e-01, 3.1231e-01, 7.6664e-01,  ..., 9.6207e-01,
#            8.2500e-01, 6.8793e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 6.0937e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[7.0493e-01, 7.0493e-01, 8.9200e-01,  ..., 1.5828e+00,
#            1.2978e+00, 1.0128e+00],
#           [7.0493e-01, 7.0493e-01, 8.9200e-01,  ..., 1.5828e+00,
#            1.2978e+00, 1.0128e+00],
#           [1.1048e+00, 1.1048e+00, 1.2642e+00,  ..., 1.7029e+00,
#            1.3325e+00, 9.6209e-01],
#           ...,
#           [4.3926e-01, 4.3926e-01, 4.4618e-01,  ..., 8.3588e-01,
#            5.4129e-01, 2.4670e-01],
#           [3.7775e-01, 3.7775e-01, 4.4190e-01,  ..., 6.4420e-01,
#            4.1337e-01, 1.8253e-01],
#           [3.1624e-01, 3.1624e-01, 4.3762e-01,  ..., 4.5252e-01,
#            2.8544e-01, 1.1836e-01]],
#
#          [[6.5552e-01, 6.5552e-01, 8.8656e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.5552e-01, 6.5552e-01, 8.8656e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [5.3758e-01, 5.3758e-01, 7.5291e-01,  ..., 5.5897e-02,
#            1.4052e-01, 2.2515e-01],
#           ...,
#           [5.8264e-01, 5.8264e-01, 5.1517e-01,  ..., 1.2300e+00,
#            1.2034e+00, 1.1768e+00],
#           [2.9577e-01, 2.9577e-01, 4.2130e-01,  ..., 9.7769e-01,
#            1.0062e+00, 1.0346e+00],
#           [8.9034e-03, 8.9034e-03, 3.2743e-01,  ..., 7.2537e-01,
#            8.0895e-01, 8.9252e-01]],
#
#          [[1.4317e+00, 1.4317e+00, 1.2060e+00,  ..., 4.6733e-01,
#            9.0371e-01, 1.3401e+00],
#           [1.4317e+00, 1.4317e+00, 1.2060e+00,  ..., 4.6733e-01,
#            9.0371e-01, 1.3401e+00],
#           [1.4860e+00, 1.4860e+00, 1.6499e+00,  ..., 1.1318e+00,
#            1.3527e+00, 1.5736e+00],
#           ...,
#           [6.4580e-01, 6.4580e-01, 8.6349e-01,  ..., 1.1563e+00,
#            1.1362e+00, 1.1161e+00],
#           [8.4330e-01, 8.4330e-01, 1.0667e+00,  ..., 1.5308e+00,
#            1.3692e+00, 1.2076e+00],
#           [1.0408e+00, 1.0408e+00, 1.2698e+00,  ..., 1.9052e+00,
#            1.6022e+00, 1.2991e+00]],
#
#          ...,
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.2394e-01, 2.4787e-01],
#           [4.2610e-03, 4.2610e-03, 2.1305e-03,  ..., 2.8505e-01,
#            3.2532e-01, 3.6559e-01],
#           [8.5219e-03, 8.5219e-03, 4.2610e-03,  ..., 5.7010e-01,
#            5.2670e-01, 4.8330e-01]],
#
#          [[7.0464e-01, 7.0464e-01, 5.4184e-01,  ..., 2.9575e-01,
#            1.4788e-01, 0.0000e+00],
#           [7.0464e-01, 7.0464e-01, 5.4184e-01,  ..., 2.9575e-01,
#            1.4788e-01, 0.0000e+00],
#           [5.9533e-01, 5.9533e-01, 4.6066e-01,  ..., 1.4788e-01,
#            1.2728e-01, 1.0669e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 1.0604e-01,  ..., 9.4644e-01,
#            1.1817e+00, 1.4170e+00],
#           [2.1673e-01, 2.1673e-01, 3.2019e-01,  ..., 1.0147e+00,
#            1.0453e+00, 1.0758e+00],
#           [4.3345e-01, 4.3345e-01, 5.3433e-01,  ..., 1.0831e+00,
#            9.0878e-01, 7.3451e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            3.9855e-01, 7.9710e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            3.9855e-01, 7.9710e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.9927e-01, 3.9855e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[3.1115e-01, 3.1115e-01, 7.1337e-01,  ..., 2.0446e-01,
#            3.3880e-01, 4.7315e-01],
#           [3.1115e-01, 3.1115e-01, 7.1337e-01,  ..., 2.0446e-01,
#            3.3880e-01, 4.7315e-01],
#           [7.9059e-01, 7.9059e-01, 1.2538e+00,  ..., 8.3412e-01,
#            8.5673e-01, 8.7934e-01],
#           ...,
#           [1.1661e-01, 1.1661e-01, 3.4180e-01,  ..., 5.7078e-01,
#            8.9051e-01, 1.2102e+00],
#           [1.6703e-01, 1.6703e-01, 3.2049e-01,  ..., 2.8539e-01,
#            6.4118e-01, 9.9697e-01],
#           [2.1746e-01, 2.1746e-01, 2.9918e-01,  ..., 0.0000e+00,
#            3.9186e-01, 7.8371e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.4892e-01,
#            2.2446e-01, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.4892e-01,
#            2.2446e-01, 0.0000e+00],
#           [4.0232e-01, 4.0232e-01, 3.3510e-01,  ..., 8.2746e-01,
#            5.7242e-01, 3.1738e-01],
#           ...,
#           [2.4507e-01, 2.4507e-01, 3.3152e-01,  ..., 2.8037e-01,
#            5.3407e-01, 7.8777e-01],
#           [2.0448e-01, 2.0448e-01, 2.8297e-01,  ..., 6.1011e-01,
#            6.8678e-01, 7.6345e-01],
#           [1.6388e-01, 1.6388e-01, 2.3441e-01,  ..., 9.3985e-01,
#            8.3949e-01, 7.3913e-01]],
#
#          [[8.6379e-01, 8.6379e-01, 1.0015e+00,  ..., 1.3862e+00,
#            8.8558e-01, 3.8498e-01],
#           [8.6379e-01, 8.6379e-01, 1.0015e+00,  ..., 1.3862e+00,
#            8.8558e-01, 3.8498e-01],
#           [1.3470e+00, 1.3470e+00, 1.5417e+00,  ..., 2.1867e+00,
#            1.5585e+00, 9.3021e-01],
#           ...,
#           [6.0702e-01, 6.0702e-01, 7.0387e-01,  ..., 1.0029e+00,
#            1.3476e+00, 1.6923e+00],
#           [6.8850e-01, 6.8850e-01, 7.8444e-01,  ..., 1.3210e+00,
#            1.3643e+00, 1.4077e+00],
#           [7.6998e-01, 7.6998e-01, 8.6500e-01,  ..., 1.6390e+00,
#            1.3811e+00, 1.1231e+00]],
#
#          ...,
#
#          [[8.5474e-02, 8.5474e-02, 4.2737e-02,  ..., 5.2584e-01,
#            2.6292e-01, 0.0000e+00],
#           [8.5474e-02, 8.5474e-02, 4.2737e-02,  ..., 5.2584e-01,
#            2.6292e-01, 0.0000e+00],
#           [4.2737e-02, 4.2737e-02, 2.1369e-02,  ..., 2.6292e-01,
#            1.3146e-01, 0.0000e+00],
#           ...,
#           [2.7700e-01, 2.7700e-01, 1.3850e-01,  ..., 3.6221e-02,
#            1.8110e-02, 0.0000e+00],
#           [1.3850e-01, 1.3850e-01, 6.9249e-02,  ..., 2.3043e-01,
#            1.1522e-01, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.2465e-01,
#            2.1232e-01, 0.0000e+00]],
#
#          [[6.3911e-01, 6.3911e-01, 8.2091e-01,  ..., 1.0264e+00,
#            9.3884e-01, 8.5123e-01],
#           [6.3911e-01, 6.3911e-01, 8.2091e-01,  ..., 1.0264e+00,
#            9.3884e-01, 8.5123e-01],
#           [3.1955e-01, 3.1955e-01, 4.1045e-01,  ..., 7.1574e-01,
#            8.2840e-01, 9.4107e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 1.3133e-01,  ..., 7.9661e-01,
#            8.6865e-01, 9.4069e-01],
#           [1.4645e-01, 1.4645e-01, 3.4039e-01,  ..., 9.0972e-01,
#            9.4773e-01, 9.8573e-01],
#           [2.9289e-01, 2.9289e-01, 5.4946e-01,  ..., 1.0228e+00,
#            1.0268e+00, 1.0308e+00]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.4270e-02, 4.8541e-02],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.4270e-02, 4.8541e-02],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.2135e-02, 2.4270e-02],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[4.0317e-01, 4.0317e-01, 7.6910e-01,  ..., 1.1966e+00,
#            9.4269e-01, 6.8883e-01],
#           [4.0317e-01, 4.0317e-01, 7.6910e-01,  ..., 1.1966e+00,
#            9.4269e-01, 6.8883e-01],
#           [1.1050e+00, 1.1050e+00, 1.5008e+00,  ..., 1.3559e+00,
#            1.0686e+00, 7.8139e-01],
#           ...,
#           [8.3278e-01, 8.3278e-01, 1.2136e+00,  ..., 1.3470e+00,
#            1.2247e+00, 1.1024e+00],
#           [1.4860e+00, 1.4860e+00, 1.5424e+00,  ..., 9.9520e-01,
#            9.7730e-01, 9.5940e-01],
#           [2.1392e+00, 2.1392e+00, 1.8713e+00,  ..., 6.4335e-01,
#            7.2985e-01, 8.1635e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [3.0621e-01, 3.0621e-01, 2.7505e-01,  ..., 1.6892e-01,
#            2.1517e-01, 2.6141e-01],
#           ...,
#           [7.9824e-01, 7.9824e-01, 5.7065e-01,  ..., 1.3094e+00,
#            1.5680e+00, 1.8266e+00],
#           [3.9912e-01, 3.9912e-01, 5.4425e-01,  ..., 1.3447e+00,
#            1.5667e+00, 1.7887e+00],
#           [0.0000e+00, 0.0000e+00, 5.1786e-01,  ..., 1.3800e+00,
#            1.5654e+00, 1.7508e+00]],
#
#          [[1.0966e+00, 1.0966e+00, 1.3485e+00,  ..., 6.5120e-02,
#            5.7752e-01, 1.0899e+00],
#           [1.0966e+00, 1.0966e+00, 1.3485e+00,  ..., 6.5120e-02,
#            5.7752e-01, 1.0899e+00],
#           [1.7557e+00, 1.7557e+00, 2.0501e+00,  ..., 9.1368e-01,
#            1.0887e+00, 1.2637e+00],
#           ...,
#           [1.8658e+00, 1.8658e+00, 2.3791e+00,  ..., 2.5195e+00,
#            2.1075e+00, 1.6956e+00],
#           [1.4747e+00, 1.4747e+00, 2.1142e+00,  ..., 2.3305e+00,
#            1.9677e+00, 1.6049e+00],
#           [1.0837e+00, 1.0837e+00, 1.8494e+00,  ..., 2.1416e+00,
#            1.8279e+00, 1.5142e+00]],
#
#          ...,
#
#          [[9.5211e-02, 9.5211e-02, 4.7606e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [9.5211e-02, 9.5211e-02, 4.7606e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [4.7606e-02, 4.7606e-02, 2.3803e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [2.8755e-01, 2.8755e-01, 1.4377e-01,  ..., 0.0000e+00,
#            4.1968e-01, 8.3936e-01],
#           [1.4377e-01, 1.4377e-01, 7.1887e-02,  ..., 0.0000e+00,
#            4.0681e-01, 8.1363e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            3.9395e-01, 7.8790e-01]],
#
#          [[4.3924e-01, 4.3924e-01, 5.5869e-01,  ..., 3.0885e-01,
#            1.5442e-01, 0.0000e+00],
#           [4.3924e-01, 4.3924e-01, 5.5869e-01,  ..., 3.0885e-01,
#            1.5442e-01, 0.0000e+00],
#           [2.1962e-01, 2.1962e-01, 2.7934e-01,  ..., 1.8082e-01,
#            2.2744e-01, 2.7405e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 2.6971e-01,  ..., 1.2851e+00,
#            9.0567e-01, 5.2624e-01],
#           [1.3768e-01, 1.3768e-01, 5.1134e-01,  ..., 1.1967e+00,
#            9.3962e-01, 6.8253e-01],
#           [2.7535e-01, 2.7535e-01, 7.5297e-01,  ..., 1.1083e+00,
#            9.7356e-01, 8.3883e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.4653e-01, 4.9307e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.4653e-01, 4.9307e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            1.2327e-01, 2.4653e-01],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]], device='cuda:0',
#        grad_fn=<AvgPool2DBackward>)
# ipdb> res[0].size()
# torch.Size([96, 350, 526])
# ipdb> l
#     116
#     117     def forward(self, x):
#     118         res = x
#     119         for l in self.layers:
#     120             res.orig = x
# --> 121             nres = l(res)
#     122             # We have to remove res.orig to avoid hanging refs and therefore memory leaks
#     123             res.orig = None
#     124             res = nres
#     125         return res
#     126
#
# ipdb> u
# > /home/s/S.Rasp/miniconda3/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py(489)__call__()
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ipdb> u
# > /home/s/S.Rasp/miniconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py(20)loss_batch()
#      18     if not is_listy(xb): xb = [xb]
#      19     if not is_listy(yb): yb = [yb]
# ---> 20     out = model(*xb)
#      21     out = cb_handler.on_loss_begin(out)
#      22
#
# ipdb> xb
# [tensor([[[[-1.8655, -1.8655, -1.8655,  ..., -0.7649, -0.6660, -1.7559],
#           [-1.8655, -1.8655, -1.8655,  ...,  1.0530,  0.2745, -1.0089],
#           [-1.8655, -1.8551, -1.8604,  ...,  0.3756,  0.3945, -1.2902],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -1.8119, -1.7206, -1.7027],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.9222, -1.8488, -1.8861],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.6984, -1.8219, -1.8021]],
#
#          [[-1.5838, -1.5838, -1.5838,  ..., -0.5693, -0.4246, -1.5547],
#           [-1.5838, -1.5838, -1.5838,  ...,  1.2670,  0.5083, -0.7869],
#           [-1.5838, -1.5723, -1.5781,  ...,  0.5665,  0.6161, -1.0871],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ..., -1.5983, -1.5007, -1.4817],
#           [-2.0357, -2.0357, -2.0357,  ..., -1.7179, -1.6381, -1.6785],
#           [-2.0357, -2.0357, -2.0357,  ..., -1.4772, -1.6090, -1.6241]],
#
#          [[-0.9330, -0.9330, -0.9330,  ..., -0.1344,  0.1722, -0.8423],
#           [-0.9330, -0.9330, -0.9330,  ...,  1.6351,  1.0524, -0.0826],
#           [-0.9330, -0.9206, -0.9268,  ...,  0.9302,  1.1314, -0.4288],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ..., -1.2583, -1.1582, -1.1388],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.3819, -1.2993, -1.3410],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.1342, -1.2693, -1.2849]]],
#
#
#         [[[ 1.8159,  1.7472,  1.8284,  ..., -1.8303, -1.7720, -1.7344],
#           [ 1.9523,  1.9048,  1.9448,  ..., -1.8365, -1.7822, -1.7790],
#           [ 1.9329,  1.9624,  1.9687,  ..., -1.8403, -1.7943, -1.7685],
#           ...,
#           [-1.3144, -1.6250, -1.6684,  ...,  0.6514,  0.3670,  0.1464],
#           [-1.6082, -1.6138, -1.5542,  ...,  0.6861,  0.7521,  0.6124],
#           [-1.2770, -1.5242, -1.1003,  ...,  1.0767,  1.0026,  0.7795]],
#
#          [[ 2.0021,  1.9300,  1.9987,  ..., -1.5604, -1.4948, -1.4465],
#           [ 2.1403,  2.0868,  2.1176,  ..., -1.5674, -1.5063, -1.5027],
#           [ 2.1207,  2.1423,  2.1421,  ..., -1.5717, -1.5198, -1.4909],
#           ...,
#           [-1.1243, -1.4503, -1.4962,  ...,  0.7518,  0.4506,  0.2814],
#           [-1.4325, -1.4385, -1.3756,  ...,  0.7490,  0.8258,  0.7258],
#           [-1.0853, -1.3442, -0.9012,  ...,  1.1513,  1.0785,  0.8729]],
#
#          [[ 2.2472,  2.1719,  2.2121,  ..., -0.8884, -0.8137, -0.7592],
#           [ 2.3824,  2.3197,  2.3304,  ..., -0.8964, -0.8267, -0.8226],
#           [ 2.3633,  2.3682,  2.3548,  ..., -0.9013, -0.8420, -0.8093],
#           ...,
#           [-0.7872, -1.1210, -1.1683,  ...,  0.7800,  0.5073,  0.3283],
#           [-1.1027, -1.1088, -1.0442,  ...,  0.7796,  0.8604,  0.7493],
#           [-0.7474, -1.0119, -0.5605,  ...,  1.1488,  1.0729,  0.8558]]],
#
#
#         [[[-2.0533, -2.0533, -2.0532,  ...,  1.0050,  0.1668, -1.2608],
#           [-2.0414, -2.0305, -2.0291,  ...,  0.8782,  0.6915,  0.7807],
#           [-2.0268, -2.0324, -2.0210,  ...,  1.2045,  0.6524,  1.1939],
#           ...,
#           [-1.1804, -1.2054, -1.2275,  ..., -1.7117, -1.7208, -1.4826],
#           [-1.1186, -1.2147, -1.2364,  ..., -1.5740, -1.2583, -1.5551],
#           [-0.6667, -1.1549, -1.1684,  ..., -1.2968, -0.6249, -1.0020]],
#
#          [[-1.9153, -1.9153, -1.9152,  ...,  1.0916,  0.3007, -1.0913],
#           [-1.9022, -1.8903, -1.8889,  ...,  0.9758,  0.7985,  0.9084],
#           [-1.8864, -1.8925, -1.8801,  ...,  1.3215,  0.7584,  1.3118],
#           ...,
#           [-0.9970, -1.0231, -1.0461,  ..., -1.5326, -1.5207, -1.2723],
#           [-0.9327, -1.0328, -1.0554,  ..., -1.3773, -1.0427, -1.3673],
#           [-0.4632, -0.9705, -0.9846,  ..., -1.0973, -0.4109, -0.8200]],
#
#          [[-1.4399, -1.4399, -1.4398,  ...,  1.3450,  0.7051, -0.5677],
#           [-1.4248, -1.4110, -1.4093,  ...,  1.2304,  1.1738,  1.4339],
#           [-1.4065, -1.4135, -1.3992,  ...,  1.5990,  1.0322,  1.5792],
#           ...,
#           [-0.7217, -0.7480, -0.7711,  ..., -1.1071, -1.1543, -0.9515],
#           [-0.6570, -0.7577, -0.7805,  ..., -0.9457, -0.6678, -1.0851],
#           [-0.1852, -0.6950, -0.7092,  ..., -0.7082, -0.0269, -0.5033]]],
#
#
#         [[[-2.1179, -2.1179, -2.1179,  ..., -1.4007, -1.5110, -1.3670],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.4606, -1.4586, -1.4430],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.4636, -1.5219, -1.5391],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ...,  1.6919,  1.9411,  1.9761],
#           [-2.1179, -2.1179, -2.1179,  ...,  1.6996,  1.9345,  1.8130],
#           [-2.1179, -2.1179, -2.1179,  ...,  1.1084,  1.4170,  1.6521]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -1.2291, -1.3415, -1.1947],
#           [-2.0357, -2.0357, -2.0357,  ..., -1.2901, -1.2881, -1.2722],
#           [-2.0357, -2.0357, -2.0357,  ..., -1.2932, -1.3527, -1.3702],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ...,  1.8718,  2.1670,  2.1138],
#           [-2.0357, -2.0357, -2.0357,  ...,  1.8670,  2.1072,  1.9829],
#           [-2.0357, -2.0357, -2.0357,  ...,  1.2626,  1.5781,  1.8184]],
#
#          [[-1.8044, -1.8044, -1.8044,  ..., -0.8375, -0.9488, -0.8034],
#           [-1.8044, -1.8044, -1.8044,  ..., -0.8980, -0.8960, -0.8802],
#           [-1.8044, -1.8044, -1.8044,  ..., -0.9010, -0.9599, -0.9773],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ...,  2.0224,  2.3694,  2.2733],
#           [-1.8044, -1.8044, -1.8044,  ...,  2.0809,  2.2872,  2.1850],
#           [-1.8044, -1.8044, -1.8044,  ...,  1.4792,  1.7599,  2.0255]]]],
#        device='cuda:0')]
# ipdb> len(xb)
# 1
# ipdb> xb[0].size()
# torch.Size([4, 3, 350, 525])
# ipdb> q

# %%
size
# Out:
# array([350, 525])

# %%
for i, r in df.iterrows():
    img = PIL.Image.open(SSDDIR + r['fn'])
    print(np.array(img).shape)
# Out:
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)
# (1400, 2100, 3)

# %%
for i, r in df.iterrows():
    img = PIL.Image.open(r['mask'])
    print(np.array(img).shape)
# Out:
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
# (1400, 2100)
